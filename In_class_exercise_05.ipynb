# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavya2810/Bhavya_INFO5731/blob/master/In_class_exercise_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fifth In-class-exercise (9/30/2020, 20 points in total)

# %% [markdown]
# In exercise-03, I asked you to collected 500 textual data based on your own information needs (If you didn't collect the textual data, you should recollect for this exercise). Now we need to think about how to represent the textual data for text classification. In this exercise, you are required to select 10 types of features (10 types of features but absolutely more than 10 features) in the followings feature list, then represent the 500 texts with these features. The output should be in the following format:
# ![image.png](attachment:image.png)
#
# The feature list:
#
# * (1) tf-idf features
# * (2) POS-tag features: number of adjective, adverb, auxiliary, punctuation, complementizer, coordinating conjunction, subordinating conjunction, determiner, interjection, noun, possessor, preposition, pronoun, quantifier, verb, and other. (select some of them if you use pos-tag features)
# * (3) Linguistic features:
#   * number of right-branching nodes across all constituent types
#   * number of right-branching nodes for NPs only
#   * number of left-branching nodes across all constituent types
#   * number of left-branching nodes for NPs only
#   * number of premodifiers across all constituent types
#   * number of premodifiers within NPs only
#   * number of postmodifiers across all constituent types
#   * number of postmodifiers within NPs only
#   * branching index across all constituent types, i.e. the number of right-branching nodes minus number of left-branching nodes
#   * branching index for NPs only
#   * branching weight index: number of tokens covered by right-branching nodes minus number of tokens covered by left-branching nodes across all categories
#   * branching weight index for NPs only
#   * modification index, i.e. the number of premodifiers minus the number of postmodifiers across all categories
#   * modification index for NPs only
#   * modification weight index: length in tokens of all premodifiers minus length in tokens of all postmodifiers across all categories
#   * modification weight index for NPs only
#   * coordination balance, i.e. the maximal length difference in coordinated constituents
#
#   * density (density can be calculated using the ratio of folowing function words to content words) of determiners/quantifiers
#   * density of pronouns
#   * density of prepositions
#   * density of punctuation marks, specifically commas and semicolons
#   * density of auxiliary verbs
#   * density of conjunctions
#   * density of different pronoun types: Wh, 1st, 2nd, and 3rd person pronouns
#
#   * maximal and average NP length
#   * maximal and average AJP length
#   * maximal and average PP length
#   * maximal and average AVP length
#   * sentence length
#
# * Other features in your mind (ie., pre-defined patterns)

# %% [markdown]
# # **Extracting Data**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
main_text = [] # List to store Review headings
sub_text =[] #List to store reviews
for number in range(52):
  link = "https://www.flipkart.com/nokia-139cm-55-inch-ultra-hd-4k-led-smart-android-tv-sound-jbl/product-reviews/itmffvfvyztsmfmq?pid=TVSFFVFVJEGZ3R5H&lid=LSTTVSFFVFVJEGZ3R5HW9DJ5W&marketplace=FLIPKART&page=" + str(number) # Generating link dynamically
  page = requests.get(link) # Accessing the webpage
  soup = BeautifulSoup(page.text, 'html.parser')
  main_reviews = soup.find_all(class_='_2xg6Ul') # Getting the Review Heading by using the class name
  text_reviews = soup.find_all(class_='qwjRop') # Getting the full reviews by using the class name
  for ele, sub_ele in zip(main_reviews, text_reviews) : # Iterating through the list
      main_text.append(ele.text) #Appending to empty list
      sub_text.append(sub_ele.text)
df = pd.DataFrame(list(zip(main_text, sub_text)), columns =['Glimpse of Review', 'Full Review'])  # Creating Dataframe
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 510
#                                      Glimpse of Review                                        Full Review
# 0    Review from Technology Gyan: Almost everything...  This 55" 4K Nokia TV at this price point comes...
# 1                                    Terrific purchase  This might seem to be awkward, but this is the...
# 2                                            Brilliant  I must say it is best decision to by Nokia TV....
# 3                                  Best in the market!  Flipcart delivered the Product in less than 24...
# 4                                          Pretty good  Pros1) Picture Quality is good, micro dimming ...
# ..                                                 ...                                                ...
# 505                                Best in the market!                    Best Quality for nokiaREAD MORE
# 506                                           Horrible  Although all things good about this tv, one th...
# 507                                          Wonderful              Very nice tv & sound is bestREAD MORE
# 508                                               Nice  Some bleeding on the screen. Sound is okay. Pi...
# 509                                     Simply awesome  Got it today.   Wow. Five Stars. Really  an am...
#
# [510 rows x 2 columns]

# %% [markdown]
# # **Preprocessing Data**

# %% [markdown]
# **Converting to lower case**

# %%
df['After Preprocessing'] = df['Full Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#                                      Glimpse of Review  ...                                After Preprocessing
# 0    Review from Technology Gyan: Almost everything...  ...  this 55" 4k nokia tv at this price point comes...
# 1                                    Terrific purchase  ...  this might seem to be awkward, but this is the...
# 2                                            Brilliant  ...  i must say it is best decision to by nokia tv....
# 3                                  Best in the market!  ...  flipcart delivered the product in less than 24...
# 4                                          Pretty good  ...  pros1) picture quality is good, micro dimming ...
# ..                                                 ...  ...                                                ...
# 505                                Best in the market!  ...                    best quality for nokiaread more
# 506                                           Horrible  ...  although all things good about this tv, one th...
# 507                                          Wonderful  ...              very nice tv & sound is bestread more
# 508                                               Nice  ...  some bleeding on the screen. sound is okay. pi...
# 509                                     Simply awesome  ...  got it today. wow. five stars. really an amazi...
#
# [510 rows x 3 columns]

# %% [markdown]
# **Removing Punctuation**

# %%
df['After Preprocessing'] = df['After Preprocessing'].str.replace('[^\w\s]','')
df
# Out:
#                                      Glimpse of Review  ...                                After Preprocessing
# 0    Review from Technology Gyan: Almost everything...  ...  this 55 4k nokia tv at this price point comes ...
# 1                                    Terrific purchase  ...  this might seem to be awkward but this is the ...
# 2                                            Brilliant  ...  i must say it is best decision to by nokia tv ...
# 3                                  Best in the market!  ...  flipcart delivered the product in less than 24...
# 4                                          Pretty good  ...  pros1 picture quality is good micro dimming wo...
# ..                                                 ...  ...                                                ...
# 505                                Best in the market!  ...                    best quality for nokiaread more
# 506                                           Horrible  ...  although all things good about this tv one thi...
# 507                                          Wonderful  ...               very nice tv  sound is bestread more
# 508                                               Nice  ...  some bleeding on the screen sound is okay pict...
# 509                                     Simply awesome  ...  got it today wow five stars really an amazing ...
#
# [510 rows x 3 columns]

# %% [markdown]
# **Removing Numerics**

# %%
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))

# %% [markdown]
# **Removing Special Characters**

# %%
import re
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
df
# Out:
#                                      Glimpse of Review  ...                                After Preprocessing
# 0    Review from Technology Gyan: Almost everything...  ...  this  k nokia tv at this price point comes wit...
# 1                                    Terrific purchase  ...  this might seem to be awkward but this is the ...
# 2                                            Brilliant  ...  i must say it is best decision to by nokia tv ...
# 3                                  Best in the market!  ...  flipcart delivered the product in less than  h...
# 4                                          Pretty good  ...  pros picture quality is good micro dimming wor...
# ..                                                 ...  ...                                                ...
# 505                                Best in the market!  ...                    best quality for nokiaread more
# 506                                           Horrible  ...  although all things good about this tv one thi...
# 507                                          Wonderful  ...               very nice tv  sound is bestread more
# 508                                               Nice  ...  some bleeding on the screen sound is okay pict...
# 509                                     Simply awesome  ...  got it today wow five stars really an amazing ...
#
# [510 rows x 3 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Package cess_cat is already up-to-date!
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Package cess_esp is already up-to-date!
#        | Downloading package chat80 to /root/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package city_database to /root/nltk_data...
#        |   Package city_database is already up-to-date!
#        | Downloading package cmudict to /root/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# **Removing Stop Words**

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#                                      Glimpse of Review  ...                                After Preprocessing
# 0    Review from Technology Gyan: Almost everything...  ...  k nokia tv price point comes almost everything...
# 1                                    Terrific purchase  ...  might seem awkward first led tv home flat tv n...
# 2                                            Brilliant  ...  must say best decision nokia tv device feature...
# 3                                  Best in the market!  ...  flipcart delivered product less hrs really ama...
# 4                                          Pretty good  ...  pros picture quality good micro dimming works ...
# ..                                                 ...  ...                                                ...
# 505                                Best in the market!  ...                             best quality nokiaread
# 506                                           Horrible  ...  although things good tv one thing found displa...
# 507                                          Wonderful  ...                             nice tv sound bestread
# 508                                               Nice  ...  bleeding screen sound okay picture quality goo...
# 509                                     Simply awesome  ...  got today wow five stars really amazing produc...
#
# [510 rows x 3 columns]

# %% [markdown]
# **Spelling Correction**

# %%
from textblob import TextBlob
df['After Preprocessing'].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0      k nikita to price point comes almost everythin...
# 1      might seem awkward first led to home flat to n...
# 2      must say best decision nikita to device featur...
# 3      flipcart delivered product less his really ama...
# 4      pro picture quality good micro dining works we...
#                              ...
# 505                               best quality nokiaread
# 506    although things good to one thing found displa...
# 507                               nice to sound bedstead
# 508    bleeding screen sound okay picture quality goo...
# 509    got today now five stars really amazing produc...
# Name: After Preprocessing, Length: 510, dtype: object

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Preprocessing'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0      k nokia tv price point come almost everyth exp...
# 1      might seem awkward first led tv home flat tv n...
# 2      must say best decis nokia tv devic featur load...
# 3      flipcart deliv product le hr realli amaz quick...
# 4      pro pictur qualiti good micro dim work well jb...
#                              ...
# 505                               best qualiti nokiaread
# 506    although thing good tv one thing found display...
# 507                               nice tv sound bestread
# 508    bleed screen sound okay pictur qualiti good go...
# 509    got today wow five star realli amaz product qu...
# Name: After Preprocessing, Length: 510, dtype: object

# %% [markdown]
# **Lemmatization**

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                      Glimpse of Review  ...                                After Preprocessing
# 0    Review from Technology Gyan: Almost everything...  ...  k nokia tv price point come almost everything ...
# 1                                    Terrific purchase  ...  might seem awkward first led tv home flat tv n...
# 2                                            Brilliant  ...  must say best decision nokia tv device feature...
# 3                                  Best in the market!  ...  flipcart delivered product le hr really amazed...
# 4                                          Pretty good  ...  pro picture quality good micro dimming work we...
# ..                                                 ...  ...                                                ...
# 505                                Best in the market!  ...                             best quality nokiaread
# 506                                           Horrible  ...  although thing good tv one thing found display...
# 507                                          Wonderful  ...                             nice tv sound bestread
# 508                                               Nice  ...  bleeding screen sound okay picture quality goo...
# 509                                     Simply awesome  ...  got today wow five star really amazing product...
#
# [510 rows x 3 columns]

# %% [markdown]
# # **Parts of Speech Tagging and Features**

# %%
from nltk.tokenize import word_tokenize
pos = []
for sentence in df['After Preprocessing']:
  text = word_tokenize(sentence)
  pos.append(nltk.pos_tag(text))
pos
# Out:
# [[('k', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('point', 'NN'),
#   ('come', 'VB'),
#   ('almost', 'RB'),
#   ('everything', 'NN'),
#   ('expect', 'JJ'),
#   ('tv', 'NN'),
#   ('today', 'NN'),
#   ('time', 'NN'),
#   ('pro', 'JJ'),
#   ('con', 'NN'),
#   ('according', 'VBG'),
#   ('experiencedpros', 'JJ'),
#   ('great', 'JJ'),
#   ('quality', 'NN'),
#   ('display', 'NN'),
#   ('thin', 'JJ'),
#   ('bezel', 'NN'),
#   ('presence', 'NN'),
#   ('almost', 'RB'),
#   ('thin', 'JJ'),
#   ('bezel', 'NNS'),
#   ('change', 'VBP'),
#   ('whole', 'JJ'),
#   ('experience', 'NN'),
#   ('viewing', 'VBG'),
#   ('played', 'VBN'),
#   ('high', 'JJ'),
#   ('resolution', 'NN'),
#   ('wildlife', 'NN'),
#   ('video', 'NN'),
#   ('youtube', 'NN'),
#   ('amazed', 'VBD'),
#   ('see', 'NN'),
#   ('detail', 'NN'),
#   ('colour', 'VBP'),
#   ('sound', 'NN'),
#   ('jbl', 'NN'),
#   ('front', 'NN'),
#   ('firing', 'VBG'),
#   ('speaker', 'NN'),
#   ('could', 'MD'),
#   ('experience', 'VB'),
#   ('clear', 'JJ'),
#   ('vocal', 'JJ'),
#   ('tone', 'NN'),
#   ('dialogue', 'NN'),
#   ('aread', 'NN')],
#  [('might', 'MD'),
#   ('seem', 'VB'),
#   ('awkward', 'RB'),
#   ('first', 'RB'),
#   ('led', 'VBN'),
#   ('tv', 'NN'),
#   ('home', 'NN'),
#   ('flat', 'JJ'),
#   ('tv', 'NN'),
#   ('naturally', 'RB'),
#   ('really', 'RB'),
#   ('amazing', 'JJ'),
#   ('u', 'NN'),
#   ('specially', 'RB'),
#   ('familyand', 'VBZ'),
#   ('also', 'RB'),
#   ('surprisingly', 'RB'),
#   ('big', 'JJ'),
#   ('size', 'NN'),
#   ('conventional', 'JJ'),
#   ('family', 'NN'),
#   ('emotional', 'JJ'),
#   ('attachment', 'NN'),
#   ('brand', 'NN'),
#   ('nokia', 'JJ'),
#   ('infact', 'JJ'),
#   ('papa', 'NN'),
#   ('mom', 'NN'),
#   ('family', 'NN'),
#   ('phone', 'NN'),
#   ('nokia', 'NN'),
#   ('till', 'NN'),
#   ('date', 'NN'),
#   ('even', 'RB'),
#   ('im', 'VBZ'),
#   ('using', 'VBG'),
#   ('nokia', 'JJ'),
#   ('n', 'JJ'),
#   ('secondary', 'JJ'),
#   ('deviceso', 'NN'),
#   ('launch', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('really', 'RB'),
#   ('craze', 'JJ'),
#   ('u', 'JJ'),
#   ('though', 'IN'),
#   ('novice', 'JJ'),
#   ('tv', 'NN'),
#   ('world', 'NN'),
#   ('little', 'JJ'),
#   ('cread', 'NN')],
#  [('must', 'MD'),
#   ('say', 'VB'),
#   ('best', 'JJS'),
#   ('decision', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('device', 'NN'),
#   ('feature', 'NN'),
#   ('loaded', 'VBD'),
#   ('dolby', 'JJ'),
#   ('vision', 'NN'),
#   ('astonishing', 'VBG'),
#   ('amazing', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('dolby', 'NN'),
#   ('vision', 'NN'),
#   ('intelligent', 'NN'),
#   ('dimming', 'VBG'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('job', 'NN'),
#   ('perfectly', 'RB'),
#   ('steal', 'JJ'),
#   ('deal', 'NN'),
#   ('guy', 'NN'),
#   ('google', 'NN'),
#   ('assistant', 'JJ'),
#   ('remote', 'NN'),
#   ('coming', 'VBG'),
#   ('handy', 'JJ'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('nokia', 'JJ'),
#   ('quality', 'NN'),
#   ('productthanks', 'NNS'),
#   ('arul', 'VBP'),
#   ('jeeves', 'NNS'),
#   ('seamless', 'JJ'),
#   ('installationread', 'NN')],
#  [('flipcart', 'RB'),
#   ('delivered', 'VBN'),
#   ('product', 'NN'),
#   ('le', 'NN'),
#   ('hr', 'NN'),
#   ('really', 'RB'),
#   ('amazed', 'VBN'),
#   ('quick', 'JJ'),
#   ('delivery', 'NN'),
#   ('next', 'IN'),
#   ('surprise', 'NN'),
#   ('come', 'VBN'),
#   ('installation', 'NN'),
#   ('received', 'VBN'),
#   ('message', 'NN'),
#   ('installation', 'NN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('however', 'RB'),
#   ('got', 'VBD'),
#   ('call', 'JJ'),
#   ('day', 'NN'),
#   ('installation', 'NN'),
#   ('done', 'VBN'),
#   ('perfection', 'NN'),
#   ('talk', 'NN'),
#   ('tv', 'NN'),
#   ('sleek', 'JJ'),
#   ('tv', 'NN'),
#   ('compare', 'NN'),
#   ('existing', 'VBG'),
#   ('lg', 'NN'),
#   ('led', 'VBD'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('ok', 'JJ'),
#   ('sound', 'NN'),
#   ('good', 'JJ'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('overall', 'JJ'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('detailed', 'VBD'),
#   ('tv', 'NN'),
#   ('review', 'NN'),
#   ('post', 'NN'),
#   ('latread', 'NN')],
#  [('pro', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('micro', 'NN'),
#   ('dimming', 'VBG'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('jbl', 'JJ'),
#   ('bass', 'NN'),
#   ('reflex', 'NN'),
#   ('sound', 'NN'),
#   ('better', 'RBR'),
#   ('compare', 'NN'),
#   ('tv', 'NN'),
#   ('range', 'NN'),
#   ('k', 'NN'),
#   ('upscaling', 'VBG'),
#   ('good', 'JJ'),
#   ('need', 'NN'),
#   ('minimum', 'JJ'),
#   ('p', 'NN'),
#   ('video', 'NN'),
#   ('get', 'VB'),
#   ('better', 'JJR'),
#   ('experience', 'NN'),
#   ('fhd', 'NN'),
#   ('video', 'NN'),
#   ('super', 'JJ'),
#   ('channel', 'NN'),
#   ('hbo', 'NN'),
#   ('hd', 'NN'),
#   ('p', 'NN'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('without', 'IN'),
#   ('noise', 'NN'),
#   ('dts', 'NN'),
#   ('trusurround', 'NN'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('really', 'RB'),
#   ('feel', 'VB'),
#   ('front', 'RB'),
#   ('surround', 'NN'),
#   ('built', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('android', 'NN'),
#   ('run', 'VB'),
#   ('smoothly', 'RB'),
#   ('remote', 'JJ'),
#   ('control', 'NN'),
#   ('good', 'JJ'),
#   ('usable', 'JJ'),
#   ('key', 'JJ'),
#   ('con', 'NN'),
#   ('screen', 'NN'),
#   ('blread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('tv', 'NN'),
#   ('everything', 'NN'),
#   ('youtube', 'NN'),
#   ('hotstar', 'NN'),
#   ('amazon', 'NN'),
#   ('prime', 'JJ'),
#   ('netflix', 'NN'),
#   ('spotify', 'VB'),
#   ('voot', 'JJ'),
#   ('zee', 'NN'),
#   ('sonyliv', 'NN'),
#   ('pre', 'NN'),
#   ('installed', 'VBD'),
#   ('also', 'RB'),
#   ('u', 'JJ'),
#   ('still', 'RB'),
#   ('want', 'VBP'),
#   ('apps', 'JJ'),
#   ('android', 'JJ'),
#   ('app', 'NN'),
#   ('store', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('amazing', 'VBG'),
#   ('inch', 'NN'),
#   ('suggest', 'VBP'),
#   ('u', 'JJ'),
#   ('play', 'NN'),
#   ('hd', 'NN'),
#   ('channel', 'NNS'),
#   ('otherwise', 'RB'),
#   ('picture', 'VBP'),
#   ('burst', 'JJ'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('dont', 'NN'),
#   ('k', 'NN'),
#   ('recharge', 'NN'),
#   ('played', 'VBD'),
#   ('youtube', 'NN'),
#   ('clearity', 'NN'),
#   ('sound', 'NN'),
#   ('amazing', 'JJ'),
#   ('havent', 'NN'),
#   ('played', 'VBD'),
#   ('game', 'NN'),
#   ('till', 'NN'),
#   ('think', 'VBP'),
#   ('ram', 'NN'),
#   ('wont', 'NN'),
#   ('aread', 'NN')],
#  [('use', 'NN'),
#   ('f', 'JJ'),
#   ('series', 'NN'),
#   ('inch', 'NN'),
#   ('tv', 'NN'),
#   ('nokia', 'NN'),
#   ('bettre', 'NN'),
#   ('thismind', 'IN'),
#   ('blowing', 'VBG'),
#   ('product', 'NN'),
#   ('smooth', 'CC'),
#   ('eye', 'NN'),
#   ('strain', 'NN'),
#   ('ad', 'NN'),
#   ('ip', 'NN'),
#   ('panel', 'NN'),
#   ('provides', 'VBZ'),
#   ('good', 'JJ'),
#   ('contrast', 'NN'),
#   ('color', 'NN'),
#   ('brightness', 'NN'),
#   ('studio', 'NN'),
#   ('like', 'IN'),
#   ('sound', 'NN'),
#   ('best', 'JJS'),
#   ('india', 'NN'),
#   ('smooth', 'NN'),
#   ('o', 'RB'),
#   ('good', 'JJ'),
#   ('update', 'NN'),
#   ('bleeding', 'VBG'),
#   ('internal', 'JJ'),
#   ('reflection', 'NN'),
#   ('change', 'NN'),
#   ('viewing', 'VBG'),
#   ('angleshighlighting', 'VBG'),
#   ('feature', 'NN'),
#   ('eys', 'NNS'),
#   ('strain', 'VBP'),
#   ('free', 'JJ'),
#   ('ad', 'NN'),
#   ('ip', 'NN'),
#   ('disply', 'NN'),
#   ('panel', 'NN'),
#   ('boe', 'NN'),
#   ('good', 'JJ'),
#   ('child', 'NN'),
#   ('far', 'RB'),
#   ('better', 'RBR'),
#   ('renowned', 'JJ'),
#   ('brand', 'NN'),
#   ('jbl', 'NN'),
#   ('sound', 'VBD'),
#   ('awesome', 'JJ'),
#   ('nokia', 'JJ'),
#   ('king', 'VBG'),
#   ('segment', 'NN'),
#   ('low', 'JJ'),
#   ('priceneed', 'NN'),
#   ('imprread', 'NN')],
#  [('great', 'JJ'),
#   ('tv', 'NN'),
#   ('review', 'NN'),
#   ('second', 'JJ'),
#   ('day', 'NN'),
#   ('installation', 'NN'),
#   ('sound', 'NN'),
#   ('great', 'JJ'),
#   ('sound', 'JJ'),
#   ('jbl', 'NN'),
#   ('dolby', 'NN'),
#   ('speakerin', 'NN'),
#   ('build', 'VBP'),
#   ('soundbar', 'NN'),
#   ('need', 'NN'),
#   ('connect', 'VBP'),
#   ('external', 'JJ'),
#   ('bluetooth', 'NN'),
#   ('speaker', 'NN'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('great', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('competitor', 'NN'),
#   ('sony', 'NN'),
#   ('samsung', 'NN'),
#   ('nice', 'JJ'),
#   ('upscaling', 'JJ'),
#   ('picture', 'NN'),
#   ('need', 'NN'),
#   ('use', 'NN'),
#   ('hd', 'NN'),
#   ('set', 'VBN'),
#   ('top', 'JJ'),
#   ('box', 'NN'),
#   ('better', 'RBR'),
#   ('clarity', 'NN'),
#   ('youtube', 'JJ'),
#   ('support', 'NN'),
#   ('dolby', 'NN'),
#   ('visio', 'NN'),
#   ('hdr', 'NN'),
#   ('looking', 'VBG'),
#   ('great', 'JJ'),
#   ('connectivity', 'NN'),
#   ('bluetooth', 'DT'),
#   ('wifi', 'VBP'),
#   ('screen', 'JJ'),
#   ('mirroring', 'VBG'),
#   ('nice', 'JJ'),
#   ('prime', 'JJ'),
#   ('video', 'NN'),
#   ('running', 'VBG'),
#   ('nice', 'JJ'),
#   ('value', 'NN'),
#   ('fread', 'NN')],
#  [('excellent', 'JJ'),
#   ('tv', 'NN'),
#   ('worth', 'NN'),
#   ('every', 'DT'),
#   ('penny', 'NN'),
#   ('think', 'VBP'),
#   ('best', 'JJS'),
#   ('tv', 'NN'),
#   ('market', 'NN'),
#   ('smart', 'JJ'),
#   ('tv', 'NN'),
#   ('pure', 'NN'),
#   ('design', 'NN'),
#   ('excellent', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('jbl', 'VBP'),
#   ('need', 'VBP'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('highly', 'RB'),
#   ('good', 'JJ'),
#   ('enjoying', 'NN'),
#   ('lot', 'NN'),
#   ('viewing', 'VBG'),
#   ('nokia', 'NNS'),
#   ('tvread', 'NN')],
#  [('providing', 'VBG'),
#   ('amazon', 'JJ'),
#   ('prime', 'JJ'),
#   ('support', 'NN'),
#   ('update', 'JJ'),
#   ('tv', 'NN'),
#   ('awesome', 'NN'),
#   ('audio', 'JJ'),
#   ('quality', 'NN'),
#   ('fabulous', 'JJ'),
#   ('k', 'NN'),
#   ('display', 'NNS'),
#   ('make', 'VBP'),
#   ('way', 'NN'),
#   ('better', 'RBR'),
#   ('smart', 'JJ'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('segment', 'NN'),
#   ('love', 'NN'),
#   ('nokia', 'JJ'),
#   ('product', 'NN'),
#   ('bcoz', 'NN'),
#   ('build', 'VBP'),
#   ('quality', 'NN'),
#   ('unique', 'JJ'),
#   ('featuresread', 'NN')],
#  [('ifff', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('planing', 'VBG'),
#   ('premium', 'JJ'),
#   ('tv', 'NN'),
#   ('k', 'NN'),
#   ('nokia', 'JJ'),
#   ('baap', 'NN'),
#   ('budget', 'NN'),
#   ('tv', 'NN'),
#   ('picture', 'NN'),
#   ('always', 'RB'),
#   ('like', 'IN'),
#   ('nokia', 'NNS'),
#   ('mobile', 'JJ'),
#   ('awsmbuilt', 'JJ'),
#   ('quality', 'NN'),
#   ('look', 'VBP'),
#   ('like', 'IN'),
#   ('nokia', 'NNS'),
#   ('lumia', 'VBP'),
#   ('glossysound', 'JJ'),
#   ('quality', 'NN'),
#   ('k', 'NN'),
#   ('premium', 'JJ'),
#   ('tv', 'NN'),
#   ('jbl', 'NN'),
#   ('baap', 'NN'),
#   ('alland', 'VBP'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('also', 'RB'),
#   ('make', 'VBP'),
#   ('happy', 'JJ'),
#   ('love', 'NN'),
#   ('u', 'NN'),
#   ('nokia', 'JJ'),
#   ('u', 'JJ'),
#   ('always', 'RB'),
#   ('gv', 'VBP'),
#   ('u', 'JJ'),
#   ('satisfactioni', 'NN'),
#   ('think', 'VBP'),
#   ('go', 'VB'),
#   ('wid', 'JJ'),
#   ('tv', 'NN'),
#   ('best', 'JJS'),
#   ('tv', 'NN'),
#   ('till', 'NN'),
#   ('k', 'VB'),
#   ('one', 'CD'),
#   ('drawback', 'NN'),
#   ('cant', 'NN'),
#   ('say', 'VBP'),
#   ('anything', 'NN'),
#   ('abt', 'JJ'),
#   ('durability', 'NN'),
#   ('bcoz', 'NN'),
#   ('first', 'RB'),
#   ('tym', 'JJ'),
#   ('nokia', 'JJ'),
#   ('launch', 'JJ'),
#   ('tv', 'NN'),
#   ('hv', 'NN'),
#   ('taken', 'VBN'),
#   ('yr', 'RB'),
#   ('warranty', 'JJ'),
#   ('soo', 'NN'),
#   ('hapiee', 'NN'),
#   ('wid', 'NN'),
#   ('thatread', 'NN')],
#  [('get', 'VB'),
#   ('white', 'JJ'),
#   ('patch', 'NN'),
#   ('top', 'NN'),
#   ('right', 'NN'),
#   ('screencant', 'NN'),
#   ('play', 'VB'),
#   ('airtel', 'JJ'),
#   ('extreme', 'JJ'),
#   ('jio', 'NN'),
#   ('tv', 'NN'),
#   ('sound', 'NN'),
#   ('amazing', 'JJ'),
#   ('image', 'NN'),
#   ('dimming', 'VBG'),
#   ('amazing', 'JJ'),
#   ('give', 'JJ'),
#   ('different', 'JJ'),
#   ('feel', 'NN'),
#   ('looked', 'VBD'),
#   ('usability', 'JJ'),
#   ('seamless', 'JJ'),
#   ('lag', 'NN'),
#   ('clicking', 'VBG'),
#   ('certain', 'JJ'),
#   ('windowsread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('productpros', 'NNS'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('jbl', 'NN'),
#   ('crystal', 'NN'),
#   ('clear', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('w', 'VBP'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('good', 'JJ'),
#   ('bass', 'NN'),
#   ('thin', 'JJ'),
#   ('bazzel', 'NN'),
#   ('android', 'NN'),
#   ('handy', 'JJ'),
#   ('remote', 'VBZ'),
#   ('almost', 'RB'),
#   ('apps', 'JJ'),
#   ('like', 'IN'),
#   ('netflix', 'JJ'),
#   ('prime', 'JJ'),
#   ('sony', 'NN'),
#   ('liv', 'NN'),
#   ('hotstar', 'NN'),
#   ('e', 'NN'),
#   ('file', 'NN'),
#   ('explorer', 'NN'),
#   ('supported', 'VBD'),
#   ('install', 'JJ'),
#   ('app', 'JJ'),
#   ('explorer', 'NN'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('coloration', 'NN'),
#   ('seen', 'VBN'),
#   ('attached', 'VBN'),
#   ('image', 'NN'),
#   ('belowcons', 'NNS'),
#   ('slight', 'VBD'),
#   ('screen', 'JJ'),
#   ('bleeding', 'VBG'),
#   ('issue', 'NN'),
#   ('sometime', 'RB'),
#   ('bluetooth', 'DT'),
#   ('connectivity', 'NN'),
#   ('issue', 'NN'),
#   ('occursread', 'NN')],
#  [('doubt', 'NN'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('product', 'NN'),
#   ('get', 'VB'),
#   ('rangepicture', 'JJ'),
#   ('sound', 'JJ'),
#   ('qaulity', 'NN'),
#   ('really', 'RB'),
#   ('awesome', 'JJ'),
#   ('couple', 'JJ'),
#   ('thing', 'NN'),
#   ('noticed', 'VBD'),
#   ('product', 'NN'),
#   ('fix', 'NN'),
#   ('regular', 'JJ'),
#   ('update', 'NN'),
#   ('like', 'IN'),
#   ('detecting', 'VBG'),
#   ('ghz', 'NN'),
#   ('wifi', 'NN'),
#   ('network', 'NN'),
#   ('little', 'JJ'),
#   ('bit', 'NN'),
#   ('slowness', 'JJ'),
#   ('booting', 'VBG'),
#   ('gap', 'NN'),
#   ('panel', 'NN'),
#   ('body', 'NN'),
#   ('side', 'NN'),
#   ('corner', 'NN'),
#   ('speaker', 'NN'),
#   ('per', 'IN'),
#   ('installation', 'NN'),
#   ('guy', 'NN'),
#   ('nokia', 'JJ'),
#   ('brand', 'NN'),
#   ('manufacturing', 'VBG'),
#   ('normal', 'JJ'),
#   ('butread', 'NN')],
#  [('worth', 'JJ'),
#   ('money', 'NN'),
#   ('great', 'JJ'),
#   ('good', 'JJ'),
#   ('experience', 'NN'),
#   ('best', 'JJS'),
#   ('luck', 'NN'),
#   ('nokiaread', 'NN')],
#  [('thank', 'JJ'),
#   ('flipkart', 'JJ'),
#   ('support', 'NN'),
#   ('replacing', 'VBG'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('new', 'JJ'),
#   ('piece', 'NN'),
#   ('doesnt', 'NN'),
#   ('back', 'RB'),
#   ('light', 'JJ'),
#   ('bleedingvery', 'NN'),
#   ('soft', 'JJ'),
#   ('warm', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('soothing', 'VBG'),
#   ('soundread', 'NN')],
#  [('day', 'NN'),
#   ('purchased', 'VBD'),
#   ('discounted', 'VBN'),
#   ('price', 'NN'),
#   ('good', 'JJ'),
#   ('thing', 'NN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('product', 'NN'),
#   ('delivered', 'VBN'),
#   ('day', 'NN'),
#   ('installation', 'NN'),
#   ('happenedabout', 'IN'),
#   ('product', 'NN'),
#   ('everything', 'NN'),
#   ('look', 'NN'),
#   ('good', 'JJ'),
#   ('need', 'NN'),
#   ('time', 'NN'),
#   ('share', 'NN'),
#   ('exact', 'JJ'),
#   ('detailed', 'VBN'),
#   ('information', 'NN'),
#   ('productbut', 'NN'),
#   ('happy', 'JJ'),
#   ('service', 'NN'),
#   ('provided', 'VBD'),
#   ('installation', 'NN'),
#   ('team', 'NN'),
#   ('jeeves', 'VBZ'),
#   ('charging', 'VBG'),
#   ('movable', 'JJ'),
#   ('wall', 'NN'),
#   ('mount', 'NN'),
#   ('around', 'IN'),
#   ('r', 'FW'),
#   ('per', 'IN'),
#   ('detail', 'NN'),
#   ('free', 'JJ'),
#   ('open', 'JJ'),
#   ('box', 'NN'),
#   ('fixed', 'JJ'),
#   ('tv', 'NN'),
#   ('say', 'VBP'),
#   ('make', 'VBP'),
#   ('connection', 'NN'),
#   ('dh', 'NN'),
#   ('thread', 'NN')],
#  [('month', 'NN'),
#   ('since', 'IN'),
#   ('tv', 'NN'),
#   ('delivered', 'VBN'),
#   ('installation', 'NN'),
#   ('complete', 'JJ'),
#   ('review', 'NN'),
#   ('month', 'NN'),
#   ('purchasing', 'VBG'),
#   ('installation', 'NN'),
#   ('delivery', 'NN'),
#   ('fast', 'RB'),
#   ('reliable', 'JJ'),
#   ('product', 'NN'),
#   ('damaged', 'VBN'),
#   ('delivered', 'VBN'),
#   ('carefully', 'RB'),
#   ('kudos', 'VB'),
#   ('flipkart', 'RB'),
#   ('quick', 'JJ'),
#   ('easy', 'JJ'),
#   ('timely', 'RB'),
#   ('safe', 'JJ'),
#   ('delivery', 'NN'),
#   ('installation', 'NN'),
#   ('done', 'VBN'),
#   ('jeeves', 'NNS'),
#   ('good', 'JJ'),
#   ('handled', 'VBD'),
#   ('care', 'JJ'),
#   ('tv', 'NN'),
#   ('nowin', 'NNS'),
#   ('month', 'NN'),
#   ('use', 'VBP'),
#   ('beyond', 'IN'),
#   ('expectation', 'NN'),
#   ('purchased', 'VBN'),
#   ('tv', 'NN'),
#   ('dint', 'NN'),
#   ('wanted', 'VBD'),
#   ('go', 'VBP'),
#   ('sony', 'JJ'),
#   ('confiread', 'NN')],
#  [('using', 'VBG'),
#   ('around', 'RP'),
#   ('month', 'NN'),
#   ('writing', 'VBG'),
#   ('commentsfew', 'JJ'),
#   ('pro', 'JJ'),
#   ('pointsdelivery', 'NN'),
#   ('item', 'NN'),
#   ('delivery', 'NN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('order', 'NN'),
#   ('date', 'NN'),
#   ('product', 'NN'),
#   ('damaged', 'VBN'),
#   ('delivered', 'VBN'),
#   ('carefully', 'RB'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'RB'),
#   ('delivery', 'NN'),
#   ('person', 'NN'),
#   ('quick', 'JJ'),
#   ('easy', 'JJ'),
#   ('timely', 'RB'),
#   ('safe', 'JJ'),
#   ('delivery', 'NN'),
#   ('installation', 'NN'),
#   ('installation', 'NN'),
#   ('also', 'RB'),
#   ('done', 'VBN'),
#   ('jeeves', 'NNS'),
#   ('evening', 'VBG'),
#   ('delivery', 'NN'),
#   ('date', 'NN'),
#   ('good', 'NN'),
#   ('handled', 'VBD'),
#   ('care', 'NN'),
#   ('felt', 'NNS'),
#   ('like', 'IN'),
#   ('little', 'JJ'),
#   ('hurry', 'JJ'),
#   ('finish', 'JJ'),
#   ('installation', 'NN'),
#   ('reason', 'NN'),
#   ('buy', 'VBP'),
#   ('tread', 'NN')],
#  [('well', 'RB'),
#   ('satisfied', 'JJ'),
#   ('buy', 'VB'),
#   ('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('great', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('hat', 'WP'),
#   ('jbl', 'VBZ'),
#   ('superb', 'NN'),
#   ('clarity', 'NN'),
#   ('blass', 'NN'),
#   ('also', 'RB'),
#   ('deep', 'JJ'),
#   ('complaint', 'NN'),
#   ('product', 'NN'),
#   ('special', 'JJ'),
#   ('thanx', 'JJ'),
#   ('flipcart', 'NN'),
#   ('time', 'NN'),
#   ('delivary', 'JJ'),
#   ('service', 'NN'),
#   ('jeevas', 'NN'),
#   ('also', 'RB'),
#   ('great', 'JJ'),
#   ('overall', 'JJ'),
#   ('happy', 'JJ'),
#   ('product', 'NN'),
#   ('please', 'NN'),
#   ('go', 'VB'),
#   ('tv', 'NN'),
#   ('simply', 'RB'),
#   ('great', 'JJ'),
#   ('read', 'NN')],
#  [('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('nokia', 'JJ'),
#   ('love', 'NN'),
#   ('sound', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('tried', 'VBD'),
#   ('playing', 'VBG'),
#   ('dolby', 'NN'),
#   ('atmos', 'NNS'),
#   ('sound', 'VBD'),
#   ('awesome', 'JJ'),
#   ('happy', 'JJ'),
#   ('purchasethis', 'NN'),
#   ('tv', 'NN'),
#   ('le', 'NN'),
#   ('premium', 'NN'),
#   ('tvread', 'NN')],
#  [('beautiful', 'JJ'),
#   ('tv', 'NN'),
#   ('good', 'JJ'),
#   ('image', 'NN'),
#   ('quality', 'NN'),
#   ('much', 'RB'),
#   ('better', 'RBR'),
#   ('sound', 'JJ'),
#   ('quality', 'JJ'),
#   ('product', 'NN'),
#   ('range', 'NN'),
#   ('installation', 'NN'),
#   ('service', 'NN'),
#   ('smooth', 'CC'),
#   ('navigation', 'JJ'),
#   ('favorite', 'JJ'),
#   ('channel', 'NN'),
#   ('highly', 'RB'),
#   ('recommended', 'VBD'),
#   ('anyone', 'NN'),
#   ('going', 'VBG'),
#   ('inch', 'JJ'),
#   ('tvread', 'NN')],
#  [('brilliant', 'JJ'),
#   ('product', 'NN'),
#   ('decision', 'NN'),
#   ('right', 'JJ'),
#   ('choice', 'NN'),
#   ('nokia', 'RB'),
#   ('led', 'VBD'),
#   ('tv', 'NN'),
#   ('buy', 'NN'),
#   ('picture', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('superb', 'NN'),
#   ('nice', 'JJ'),
#   ('product', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('day', 'NN'),
#   ('delivery', 'NN'),
#   ('day', 'NN'),
#   ('installationread', 'VB')],
#  [('using', 'VBG'),
#   ('month', 'NN'),
#   ('tv', 'NN'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('isue', 'RB'),
#   ('found', 'VBN'),
#   ('picture', 'NN'),
#   ('sound', 'JJ'),
#   ('conectivity', 'NN'),
#   ('everything', 'NN'),
#   ('good', 'JJ'),
#   ('fully', 'RB'),
#   ('satisfied', 'VBN'),
#   ('read', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('product', 'NN'),
#   ('reputed', 'VBN'),
#   ('brand', 'NN'),
#   ('nokia', 'NN'),
#   ('sound', 'VBD'),
#   ('good', 'JJ'),
#   ('clear', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('quality', 'NN'),
#   ('delivery', 'NN'),
#   ('flipkart', 'NN'),
#   ('done', 'VBN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('installation', 'NN'),
#   ('carried', 'VBD'),
#   ('jeeves', 'NNS'),
#   ('day', 'NN'),
#   ('excellent', 'JJ'),
#   ('serviceread', 'NN')],
#  [('awesome', 'JJ'),
#   ('tv', 'NN'),
#   ('super', 'NN'),
#   ('display', 'NN'),
#   ('amazing', 'VBG'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('nokia', 'RB'),
#   ('provided', 'VBD'),
#   ('best', 'RBS'),
#   ('possible', 'JJ'),
#   ('latest', 'JJS'),
#   ('feature', 'NN'),
#   ('budget', 'NN'),
#   ('pricing', 'NN'),
#   ('netflix', 'NN'),
#   ('amazonprimevideo', 'NN'),
#   ('also', 'RB'),
#   ('working', 'VBG'),
#   ('good', 'JJ'),
#   ('must', 'MD'),
#   ('buy', 'VB'),
#   ('tvread', 'NN')],
#  [('excellent', 'JJ'),
#   ('tv', 'NN'),
#   ('great', 'JJ'),
#   ('sound', 'JJ'),
#   ('google', 'NN'),
#   ('assistant', 'NN'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('attractive', 'JJ'),
#   ('deal', 'NN'),
#   ('perfect', 'JJ'),
#   ('installation', 'NN'),
#   ('sagar', 'NN'),
#   ('nikamread', 'NN')],
#  [('confusion', 'NN'),
#   ('whether', 'IN'),
#   ('go', 'VB'),
#   ('lg', 'JJ'),
#   ('nokia', 'RB'),
#   ('seeing', 'VBG'),
#   ('positive', 'JJ'),
#   ('review', 'NN'),
#   ('nokia', 'RB'),
#   ('ordered', 'VBD'),
#   ('th', 'JJ'),
#   ('jan', 'NN'),
#   ('received', 'VBD'),
#   ('th', 'RB'),
#   ('installed', 'VBN'),
#   ('jivi', 'NN'),
#   ('technician', 'JJ'),
#   ('th', 'JJ'),
#   ('pro', 'FW'),
#   ('conspros', 'FW'),
#   ('excellent', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('considering', 'VBG'),
#   ('price', 'NN'),
#   ('point', 'NN'),
#   ('viewjbl', 'NN'),
#   ('speaker', 'NN'),
#   ('sounding', 'VBG'),
#   ('good', 'JJ'),
#   ('latest', 'JJS'),
#   ('android', 'JJ'),
#   ('con', 'NN'),
#   ('mm', 'NN'),
#   ('audio', 'NN'),
#   ('output', 'NN'),
#   ('option', 'NN'),
#   ('missing', 'VBG'),
#   ('hdmi', 'NN'),
#   ('usb', 'JJ'),
#   ('port', 'NN'),
#   ('placed', 'VBD'),
#   ('close', 'JJ'),
#   ('difficult', 'JJ'),
#   ('insertion', 'NN'),
#   ('removal', 'NN'),
#   ('pen', 'JJ'),
#   ('drive', 'NN'),
#   ('fitment', 'NN'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('panel', 'NN'),
#   ('pread', 'NN')],
#  [('super', 'JJ'),
#   ('tv', 'NN'),
#   ('buy', 'VB'),
#   ('waiting', 'VBG'),
#   ('many', 'JJ'),
#   ('day', 'NN'),
#   ('buy', 'VB'),
#   ('looking', 'VBG'),
#   ('good', 'JJ'),
#   ('bad', 'JJ'),
#   ('review', 'NN'),
#   ('finally', 'RB'),
#   ('order', 'NN'),
#   ('good', 'JJ'),
#   ('decision', 'NN'),
#   ('buy', 'VB'),
#   ('looking', 'VBG'),
#   ('review', 'NN'),
#   ('like', 'IN'),
#   ('looking', 'VBG'),
#   ('review', 'NN'),
#   ('dont', 'NN'),
#   ('worry', 'NN'),
#   ('guy', 'NN'),
#   ('buy', 'VB'),
#   ('delivery', 'NN'),
#   ('soon', 'RB'),
#   ('schedule', 'JJ'),
#   ('installation', 'NN'),
#   ('niceread', 'NN')],
#  [('writing', 'VBG'),
#   ('review', 'NN'),
#   ('one', 'CD'),
#   ('week', 'NN'),
#   ('use', 'NN'),
#   ('delivery', 'NN'),
#   ('installation', 'NN'),
#   ('pretty', 'IN'),
#   ('fast', 'RB'),
#   ('good', 'JJ'),
#   ('installation', 'NN'),
#   ('done', 'VBN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('delivery', 'NN'),
#   ('far', 'RB'),
#   ('experience', 'RB'),
#   ('good', 'JJ'),
#   ('tv', 'NN'),
#   ('beast', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('powered', 'VBD'),
#   ('jbl', 'NN'),
#   ('sound', 'NN'),
#   ('one', 'CD'),
#   ('main', 'JJ'),
#   ('feature', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('ask', 'VB'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('flipkart', 'NN'),
#   ('nokiaread', 'NN')],
#  [('honest', 'JJS'),
#   ('review', 'NN'),
#   ('tv', 'NN'),
#   ('good', 'JJ'),
#   ('good', 'JJ'),
#   ('purchase', 'NN'),
#   ('genuine', 'JJ'),
#   ('pricefew', 'JJ'),
#   ('thing', 'NN'),
#   ('dont', 'NN'),
#   ('like', 'IN'),
#   ('ablack', 'NN'),
#   ('screen', 'NN'),
#   ('using', 'VBG'),
#   ('volume', 'NN'),
#   ('buttonb', 'NN'),
#   ('chromecast', 'NN'),
#   ('great', 'JJ'),
#   ('connection', 'NN'),
#   ('issue', 'NN'),
#   ('wific', 'NN'),
#   ('video', 'NN'),
#   ('hang', 'NN'),
#   ('millisecond', 'NN'),
#   ('increasing', 'VBG'),
#   ('volumebug', 'NNS'),
#   ('need', 'VBP'),
#   ('fixedd', 'JJ'),
#   ('please', 'VB'),
#   ('ensure', 'VB'),
#   ('movable', 'JJ'),
#   ('wall', 'NN'),
#   ('mount', 'NN'),
#   ('offered', 'VBD'),
#   ('installation', 'NN'),
#   ('guy', 'NN'),
#   ('price', 'NN'),
#   ('fixed', 'VBD'),
#   ('properly', 'RB'),
#   ('wallin', 'JJ'),
#   ('case', 'NN'),
#   ('screw', 'NN'),
#   ('could', 'MD'),
#   ('hold', 'VB'),
#   ('tv', 'NN'),
#   ('weight', 'JJ'),
#   ('couple', 'NN'),
#   ('day', 'NN'),
#   ('read', 'VB')],
#  [('pro', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('great', 'JJ'),
#   ('great', 'JJ'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('voice', 'NN'),
#   ('control', 'NN'),
#   ('present', 'NN'),
#   ('remoteconsthere', 'WRB'),
#   ('option', 'NN'),
#   ('screen', 'NN'),
#   ('mirroring', 'VBG'),
#   ('chrome', 'JJ'),
#   ('cast', 'NN'),
#   ('worksi', 'NN'),
#   ('see', 'VBP'),
#   ('slight', 'JJ'),
#   ('back', 'RB'),
#   ('light', 'JJ'),
#   ('bleeding', 'VBG'),
#   ('one', 'CD'),
#   ('small', 'JJ'),
#   ('corner', 'NN'),
#   ('sure', 'JJ'),
#   ('major', 'JJ'),
#   ('issueno', 'NN'),
#   ('option', 'NN'),
#   ('choose', 'NN'),
#   ('brightness', 'NN'),
#   ('settingsoverall', 'JJ'),
#   ('pro', 'JJ'),
#   ('weigh', 'FW'),
#   ('higher', 'JJR'),
#   ('best', 'JJS'),
#   ('value', 'NN'),
#   ('tvread', 'NN')],
#  [('liked', 'VBN'),
#   ('much', 'RB'),
#   ('wanted', 'VBD'),
#   ('good', 'JJ'),
#   ('trustable', 'JJ'),
#   ('brand', 'NN'),
#   ('dont', 'NN'),
#   ('wanted', 'VBD'),
#   ('spend', 'JJ'),
#   ('money', 'NN'),
#   ('tv', 'NN'),
#   ('got', 'VBD'),
#   ('good', 'JJ'),
#   ('brand', 'NN'),
#   ('good', 'JJ'),
#   ('quality', 'NN'),
#   ('k', 'NN'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('latest', 'JJS'),
#   ('technology', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('delivering', 'VBG'),
#   ('expected', 'VBN'),
#   ('time', 'NN'),
#   ('installation', 'NN'),
#   ('soonread', 'NN')],
#  [('wonderful', 'JJ'),
#   ('experience', 'NN'),
#   ('picture', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('expensive', 'JJ'),
#   ('tv', 'NN'),
#   ('brand', 'NN'),
#   ('infact', 'NN'),
#   ('audio', 'JJ'),
#   ('better', 'RBR'),
#   ('samsung', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('highly', 'RB'),
#   ('recommended', 'VBN'),
#   ('read', 'NN')],
#  [('say', 'VB'),
#   ('best', 'JJS'),
#   ('decision', 'NN'),
#   ('buy', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('amazing', 'VBG'),
#   ('sound', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('one', 'CD'),
#   ('planning', 'NN'),
#   ('buy', 'VB'),
#   ('smart', 'JJ'),
#   ('tv', 'NN'),
#   ('please', 'NN'),
#   ('go', 'VB'),
#   ('nokia', 'JJ'),
#   ('fully', 'RB'),
#   ('satisfied', 'JJ'),
#   ('tv', 'NN'),
#   ('waited', 'VBD'),
#   ('day', 'NN'),
#   ('make', 'VB'),
#   ('reviewread', 'NN')],
#  [('writing', 'VBG'),
#   ('review', 'JJ'),
#   ('month', 'NN'),
#   ('usagecategory', 'JJ'),
#   ('wise', 'NN'),
#   ('rating', 'NN'),
#   ('followspicture', 'NN'),
#   ('ratting', 'VBG'),
#   ('give', 'JJ'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('enjoyed', 'VBD'),
#   ('thatsoundsrating', 'VBG'),
#   ('provided', 'VBN'),
#   ('jbl', 'NN'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('sound', 'NN'),
#   ('effect', 'NN'),
#   ('awesomepricerating', 'VBG'),
#   ('long', 'JJ'),
#   ('time', 'NN'),
#   ('waiting', 'VBG'),
#   ('buy', 'VB'),
#   ('led', 'JJ'),
#   ('tv', 'NN'),
#   ('finally', 'RB'),
#   ('nokia', 'RB'),
#   ('satisfied', 'JJ'),
#   ('price', 'NN'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('offer', 'NN'),
#   ('provided', 'VBD'),
#   ('buying', 'VBG'),
#   ('productconnectivityrating', 'VBG'),
#   ('unsatisfied', 'JJ'),
#   ('chromecast', 'NN'),
#   ('connection', 'NN'),
#   ('help', 'NN'),
#   ('broadbread', 'VB')],
#  [('buy', 'VB'),
#   ('tv', 'NN'),
#   ('week', 'NN'),
#   ('ago', 'RB'),
#   ('really', 'RB'),
#   ('nice', 'JJ'),
#   ('awesometotally', 'RB'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('service', 'NN'),
#   ('good', 'JJ'),
#   ('jeeves', 'NNS'),
#   ('give', 'VBP'),
#   ('great', 'JJ'),
#   ('response', 'NN'),
#   ('unboxing', 'VBG'),
#   ('tv', 'NN'),
#   ('totally', 'RB'),
#   ('loveit', 'JJ'),
#   ('everything', 'NN'),
#   ('read', 'NN')],
#  [('best', 'JJS'),
#   ('tv', 'NN'),
#   ('among', 'IN'),
#   ('k', 'JJ'),
#   ('tv', 'NN'),
#   ('available', 'JJ'),
#   ('special', 'JJ'),
#   ('highlight', 'NN'),
#   ('built', 'VBN'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('give', 'VB'),
#   ('real', 'JJ'),
#   ('audio', 'JJ'),
#   ('experienceit', 'NN'),
#   ('dolbi', 'NN'),
#   ('vision', 'NN'),
#   ('dts', 'NN'),
#   ('trusurround', 'NN'),
#   ('dolbi', 'NN'),
#   ('audio', 'JJ'),
#   ('intelligence', 'NN'),
#   ('dimming', 'VBG'),
#   ('lot', 'NN'),
#   ('amazing', 'JJ'),
#   ('feature', 'NN'),
#   ('truly', 'RB'),
#   ('loved', 'VBD'),
#   ('itread', 'JJ')],
#  [('perfect', 'JJ'),
#   ('tv', 'NN'),
#   ('home', 'NN'),
#   ('superb', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('real', 'JJ'),
#   ('k', 'NN'),
#   ('loved', 'VBD'),
#   ('sound', 'JJ'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('attached', 'VBD'),
#   ('tv', 'NN'),
#   ('exact', 'NN'),
#   ('like', 'IN'),
#   ('soundbar', 'NN'),
#   ('dont', 'NN'),
#   ('spend', 'VBP'),
#   ('extra', 'JJ'),
#   ('itwill', 'NN'),
#   ('review', 'NN'),
#   ('monthread', 'NN')],
#  [('choose', 'RB'),
#   ('right', 'JJ'),
#   ('product', 'NN'),
#   ('picture', 'NN'),
#   ('awesomesound', 'IN'),
#   ('quality', 'NN'),
#   ('exalent', 'NN'),
#   ('super', 'NN'),
#   ('designand', 'NN'),
#   ('super', 'NN'),
#   ('build', 'VBP'),
#   ('quality', 'JJ'),
#   ('tv', 'NN'),
#   ('like', 'IN'),
#   ('mini', 'NN'),
#   ('theateri', 'NN'),
#   ('love', 'VB'),
#   ('product', 'NN'),
#   ('bug', 'NN'),
#   ('tv', 'NN'),
#   ('fix', 'NN'),
#   ('next', 'JJ'),
#   ('update', 'JJ'),
#   ('exalent', 'JJ'),
#   ('tv', 'NN'),
#   ('read', 'NN')],
#  [('review', 'NN'),
#   ('day', 'NN'),
#   ('usage', 'JJ'),
#   ('nokia', 'JJ'),
#   ('smart', 'JJ'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('nokia', 'VBD'),
#   ('given', 'VBN'),
#   ('best', 'JJS'),
#   ('class', 'NN'),
#   ('product', 'NN'),
#   ('partnership', 'NN'),
#   ('jbl', 'JJ'),
#   ('flipkart', 'RB'),
#   ('amazed', 'JJ'),
#   ('performance', 'NN'),
#   ('product', 'NN'),
#   ('display', 'NN'),
#   ('quality', 'NN'),
#   ('mind', 'NN'),
#   ('blowing', 'JJ'),
#   ('price', 'NN'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('play', 'NN'),
#   ('without', 'IN'),
#   ('lag', 'NN'),
#   ('gb', 'NN'),
#   ('ram', 'NN'),
#   ('provide', 'VBP'),
#   ('quick', 'JJ'),
#   ('response', 'NN'),
#   ('bluetooth', 'DT'),
#   ('enable', 'JJ'),
#   ('remote', 'JJ'),
#   ('look', 'NN'),
#   ('fabulous', 'JJ'),
#   ('gb', 'NN'),
#   ('storage', 'NN'),
#   ('user', 'JJ'),
#   ('get', 'NN'),
#   ('gb', 'JJ'),
#   ('storage', 'NN'),
#   ('usage', 'JJ'),
#   ('quite', 'RB'),
#   ('enough', 'JJ'),
#   ('new', 'JJ'),
#   ('apps', 'NNS'),
#   ('get', 'VBP'),
#   ('installed', 'VBN'),
#   ('read', 'NN')],
#  [('product', 'NN'),
#   ('best', 'JJS'),
#   ('class', 'NN'),
#   ('aspect', 'NN'),
#   ('specially', 'RB'),
#   ('sound', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('diplay', 'NN'),
#   ('also', 'RB'),
#   ('great', 'JJ'),
#   ('quality', 'NN'),
#   ('find', 'VBP'),
#   ('buy', 'VB'),
#   ('forget', 'VB'),
#   ('bother', 'JJ'),
#   ('upgrading', 'VBG'),
#   ('latest', 'JJS'),
#   ('tv', 'NN'),
#   ('next', 'IN'),
#   ('five', 'CD'),
#   ('year', 'NN'),
#   ('leastone', 'NN'),
#   ('much', 'JJ'),
#   ('ready', 'JJ'),
#   ('say', 'VBP'),
#   ('yes', 'UH'),
#   ('warranty', 'JJ'),
#   ('installation', 'NN'),
#   ('company', 'NN'),
#   ('offer', 'NN'),
#   ('almost', 'RB'),
#   ('item', 'JJ'),
#   ('value', 'NN'),
#   ('extend', 'VBP'),
#   ('next', 'JJ'),
#   ('two', 'CD'),
#   ('year', 'NN'),
#   ('one', 'CD'),
#   ('year', 'NN'),
#   ('warranty', 'NN'),
#   ('come', 'VBP'),
#   ('manufacturerthanks', 'NNS'),
#   ('hmd', 'VBP'),
#   ('nokia', 'JJ'),
#   ('flipkartread', 'NN')],
#  [('good', 'JJ'),
#   ('led', 'VBD'),
#   ('tv', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('crystal', 'JJ'),
#   ('clarity', 'NN'),
#   ('picture', 'NN'),
#   ('especially', 'RB'),
#   ('k', 'JJ'),
#   ('video', 'JJ'),
#   ('awesome', 'JJ'),
#   ('watch', 'NN'),
#   ('android', 'NN'),
#   ('apps', 'NN'),
#   ('available', 'JJ'),
#   ('play', 'NN'),
#   ('store', 'NN'),
#   ('third', 'JJ'),
#   ('party', 'NN'),
#   ('apps', 'NN'),
#   ('cant', 'JJ'),
#   ('install', 'JJ'),
#   ('otherwise', 'RB'),
#   ('nokia', 'JJ'),
#   ('awesome', 'JJ'),
#   ('thanks', 'NNS'),
#   ('flipkartread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'VBP'),
#   ('like', 'IN'),
#   ('movie', 'NN'),
#   ('theatre', 'NN'),
#   ('clear', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('great', 'JJ'),
#   ('productat', 'JJ'),
#   ('night', 'NN'),
#   ('dark', 'NN'),
#   ('room', 'NN'),
#   ('change', 'NN'),
#   ('like', 'IN'),
#   ('movie', 'NN'),
#   ('theatre', 'NN'),
#   ('dolby', 'NN'),
#   ('sound', 'VBD'),
#   ('support', 'NN'),
#   ('system', 'NN'),
#   ('awesomeread', 'NN')],
#  [('thing', 'NN'),
#   ('like', 'IN'),
#   ('look', 'NN'),
#   ('premium', 'JJ'),
#   ('cool', 'NN'),
#   ('show', 'NN'),
#   ('beautiful', 'JJ'),
#   ('k', 'NN'),
#   ('wallpaper', 'NN'),
#   ('go', 'VBP'),
#   ('sleep', 'JJ'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('n', 'NN'),
#   ('unique', 'NN'),
#   ('feature', 'NN'),
#   ('trust', 'NN'),
#   ('youll', 'NN'),
#   ('amazed', 'VBD'),
#   ('thisit', 'NN'),
#   ('beautifies', 'NNS'),
#   ('living', 'VBG'),
#   ('room', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('great', 'JJ'),
#   ('good', 'JJ'),
#   ('viewing', 'VBG'),
#   ('angle', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('affordable', 'JJ'),
#   ('worth', 'NN'),
#   ('every', 'DT'),
#   ('penny', 'NN'),
#   ('pay', 'NN'),
#   ('screen', 'NN'),
#   ('mirroring', 'VBG'),
#   ('working', 'VBG'),
#   ('without', 'IN'),
#   ('delay', 'NN'),
#   ('mobile', 'JJ'),
#   ('laptop', 'JJ'),
#   ('con', 'NN'),
#   ('really', 'RB'),
#   ('change', 'JJ'),
#   ('volume', 'NN'),
#   ('button', 'NN'),
#   ('yoread', 'NN')],
#  [('really', 'RB'),
#   ('good', 'JJ'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('point', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('brilliant', 'JJ'),
#   ('par', 'NN'),
#   ('sonys', 'NN'),
#   ('lgs', 'NN'),
#   ('sound', 'NN'),
#   ('jbl', 'NN'),
#   ('crisp', 'NN'),
#   ('clear', 'JJ'),
#   ('however', 'RB'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('great', 'JJ'),
#   ('louder', 'NN'),
#   ('volume', 'NN'),
#   ('honestly', 'RB'),
#   ('true', 'JJ'),
#   ('almost', 'RB'),
#   ('tv', 'NN'),
#   ('speakerread', 'NN')],
#  [('great', 'JJ'),
#   ('tv', 'NN'),
#   ('superior', 'JJ'),
#   ('audiojbl', 'IN'),
#   ('done', 'VBN'),
#   ('outstanding', 'JJ'),
#   ('job', 'NN'),
#   ('good', 'JJ'),
#   ('video', 'NN'),
#   ('quality', 'NN'),
#   ('come', 'VBP'),
#   ('necessary', 'JJ'),
#   ('accessory', 'NN'),
#   ('including', 'VBG'),
#   ('wall', 'NN'),
#   ('mount', 'NN'),
#   ('kitcould', 'MD'),
#   ('improved', 'VB'),
#   ('ui', 'JJ'),
#   ('side', 'NN'),
#   ('like', 'IN'),
#   ('picture', 'NN'),
#   ('configuration', 'NN'),
#   ('like', 'IN'),
#   ('brightness', 'NN'),
#   ('saturation', 'NN'),
#   ('etc', 'FW'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('changed', 'VB'),
#   ('viewing', 'VBG'),
#   ('content', 'JJ'),
#   ('hope', 'NN'),
#   ('addressed', 'VBD'),
#   ('next', 'JJ'),
#   ('update', 'NN'),
#   ('definitely', 'RB'),
#   ('bang', 'JJ'),
#   ('buckread', 'NN')],
#  [('first', 'RB'),
#   ('thank', 'VB'),
#   ('much', 'JJ'),
#   ('flipkart', 'NN'),
#   ('excellent', 'JJ'),
#   ('service', 'NN'),
#   ('within', 'IN'),
#   ('hour', 'NN'),
#   ('delivery', 'NN'),
#   ('installation', 'NN'),
#   ('done', 'VBN'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('tv', 'NN'),
#   ('good', 'JJ'),
#   ('metal', 'NN'),
#   ('reviewer', 'NN'),
#   ('saying', 'VBG'),
#   ('stand', 'NN'),
#   ('made', 'VBD'),
#   ('metal', 'NN'),
#   ('solidly', 'RB'),
#   ('made', 'VBD'),
#   ('thin', 'JJ'),
#   ('upgrading', 'JJ'),
#   ('form', 'NN'),
#   ('lcd', 'CC'),
#   ('full', 'JJ'),
#   ('hd', 'NN'),
#   ('k', 'NN'),
#   ('led', 'VBD'),
#   ('stunned', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('full', 'JJ'),
#   ('hd', 'NN'),
#   ('channel', 'NN'),
#   ('good', 'JJ'),
#   ('excellent', 'NN'),
#   ('k', 'NN'),
#   ('content', 'JJ'),
#   ('look', 'NN'),
#   ('excellent', 'JJ'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('test', 'NN'),
#   ('intelligent', 'NN'),
#   ('diming', 'VBG'),
#   ('working', 'VBG'),
#   ('oread', 'NN')],
#  [('tv', 'NN'),
#   ('end', 'NN'),
#   ('ember', 'NN'),
#   ('stop', 'JJ'),
#   ('six', 'CD'),
#   ('month', 'NN'),
#   ('ive', 'JJ'),
#   ('using', 'VBG'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('system', 'NN'),
#   ('top', 'JJ'),
#   ('notch', 'NN'),
#   ('netflix', 'NN'),
#   ('dolby', 'JJ'),
#   ('vision', 'NN'),
#   ('movie', 'NN'),
#   ('see', 'VBP'),
#   ('difference', 'NN'),
#   ('amazing', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('jbl', 'NN'),
#   ('sound', 'JJ'),
#   ('bar', 'NN'),
#   ('justice', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('listening', 'VBG'),
#   ('surround', 'NN'),
#   ('sound', 'VBD'),
#   ('movie', 'NN'),
#   ('amazing', 'JJ'),
#   ('challenge', 'NN'),
#   ('find', 'VBP'),
#   ('picture', 'NN'),
#   ('default', 'NN'),
#   ('option', 'NN'),
#   ('compared', 'VBN'),
#   ('lg', 'JJ'),
#   ('tv', 'NN'),
#   ('android', 'NN'),
#   ('work', 'NN'),
#   ('smoothly', 'RB'),
#   ('without', 'IN'),
#   ('laread', 'NN')],
#  [('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('best', 'JJS'),
#   ('bright', 'JJ'),
#   ('colour', 'NN'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('nice', 'JJ'),
#   ('sound', 'NN'),
#   ('aone', 'NN'),
#   ('connectivity', 'NN'),
#   ('good', 'JJ'),
#   ('working', 'VBG'),
#   ('pessa', 'NN'),
#   ('vasoolread', 'NN')],
#  [('good', 'JJ'),
#   ('price', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('best', 'JJS'),
#   ('dolby', 'NN'),
#   ('surround', 'NN'),
#   ('best', 'RBS'),
#   ('bestread', 'NN')],
#  [('tv', 'NN'),
#   ('amazing', 'JJ'),
#   ('price', 'NN'),
#   ('point', 'NN'),
#   ('clear', 'JJ'),
#   ('movie', 'NN'),
#   ('feel', 'NN'),
#   ('like', 'IN'),
#   ('behind', 'IN'),
#   ('scene', 'NN'),
#   ('making', 'VBG'),
#   ('video', 'NN'),
#   ('still', 'RB'),
#   ('getting', 'VBG'),
#   ('use', 'NN'),
#   ('k', 'NN'),
#   ('surprised', 'VBD'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('simply', 'RB'),
#   ('awesome', 'JJ'),
#   ('viewing', 'VBG'),
#   ('angle', 'NN'),
#   ('superb', 'NN'),
#   ('actually', 'RB'),
#   ('waiting', 'VBG'),
#   ('motorola', 'JJ'),
#   ('tv', 'NN'),
#   ('read', 'VBD'),
#   ('tv', 'NN'),
#   ('decided', 'VBD'),
#   ('one', 'CD'),
#   ('right', 'JJ'),
#   ('decision', 'NN'),
#   ('seemsread', 'NN')],
#  [('best', 'JJS'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('tough', 'JJ'),
#   ('competator', 'NN'),
#   ('commom', 'NN'),
#   ('brand', 'NN'),
#   ('like', 'IN'),
#   ('samsung', 'NN'),
#   ('lg', 'NN'),
#   ('sony', 'NN'),
#   ('display', 'NN'),
#   ('vibrant', 'NN'),
#   ('need', 'VBP'),
#   ('buy', 'VB'),
#   ('home', 'NN'),
#   ('theatre', 'NN'),
#   ('sound', 'JJ'),
#   ('jbl', 'NN'),
#   ('provides', 'VBZ'),
#   ('best', 'RBS'),
#   ('experience', 'NN'),
#   ('kudos', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('hv', 'NN'),
#   ('available', 'JJ'),
#   ('sizeread', 'NN')],
#  [('im', 'NN'),
#   ('really', 'RB'),
#   ('satisfied', 'JJ'),
#   ('product', 'NN'),
#   ('glad', 'NN'),
#   ('made', 'VBD'),
#   ('purchase', 'NN'),
#   ('product', 'NN'),
#   ('mind', 'NN'),
#   ('bought', 'VBD'),
#   ('one', 'CD'),
#   ('experiencing', 'VBG'),
#   ('real', 'JJ'),
#   ('life', 'NN'),
#   ('display', 'NN'),
#   ('quality', 'NN'),
#   ('mention', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('superb', 'NN'),
#   ('jbl', 'NN'),
#   ('really', 'RB'),
#   ('known', 'VBN'),
#   ('quality', 'NN'),
#   ('u', 'JJ'),
#   ('experience', 'NN'),
#   ('dolby', 'NN'),
#   ('vision', 'NN'),
#   ('dts', 'NN'),
#   ('surround', 'NN'),
#   ('sound', 'VBD'),
#   ('really', 'RB'),
#   ('awesome', 'JJ'),
#   ('seen', 'VBN'),
#   ('review', 'NN'),
#   ('bad', 'JJ'),
#   ('connectivity', 'NN'),
#   ('issue', 'NN'),
#   ('time', 'NN'),
#   ('noread', 'JJ')],
#  [('writing', 'VBG'),
#   ('review', 'JJ'),
#   ('month', 'NN'),
#   ('usage', 'NN'),
#   ('really', 'RB'),
#   ('really', 'RB'),
#   ('love', 'VB'),
#   ('tv', 'NN'),
#   ('best', 'JJS'),
#   ('decision', 'NN'),
#   ('madepros', 'FW'),
#   ('excellent', 'JJ'),
#   ('display', 'NN'),
#   ('quality', 'NN'),
#   ('k', 'VBP'),
#   ('video', 'NN'),
#   ('run', 'NN'),
#   ('without', 'IN'),
#   ('lag', 'JJ'),
#   ('internet', 'NN'),
#   ('connectivity', 'NN'),
#   ('fine', 'VBP'),
#   ('far', 'RB'),
#   ('superb', 'JJ'),
#   ('sound', 'JJ'),
#   ('claritythanks', 'NNS'),
#   ('jbl', 'VBP'),
#   ('installation', 'NN'),
#   ('flawless', 'NN'),
#   ('guy', 'NN'),
#   ('delivered', 'VBN'),
#   ('super', 'JJ'),
#   ('friendly', 'RB'),
#   ('come', 'VBP'),
#   ('usb', 'JJ'),
#   ('port', 'NN'),
#   ('con', 'NN'),
#   ('tv', 'NN'),
#   ('updated', 'VBD'),
#   ('latest', 'JJS'),
#   ('version', 'NN'),
#   ('andriod', 'NN'),
#   ('else', 'RB'),
#   ('miss', 'JJ'),
#   ('apps', 'NN'),
#   ('bug', 'NN'),
#   ('fix', 'VBD'),
#   ('even', 'RB'),
#   ('updating', 'VBG'),
#   ('facing', 'VBG'),
#   ('restread', 'NN')],
#  [('beast', 'NN'),
#   ('price', 'NN'),
#   ('better', 'RBR'),
#   ('expected', 'VBN'),
#   ('never', 'RB'),
#   ('experienced', 'VBN'),
#   ('sound', 'JJ'),
#   ('tv', 'NN'),
#   ('far', 'RB'),
#   ('visual', 'JJ'),
#   ('quality', 'NN'),
#   ('uhd', 'JJ'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('infact', 'JJ'),
#   ('color', 'NN'),
#   ('slightly', 'RB'),
#   ('better', 'JJR'),
#   ('others', 'NNS'),
#   ('hope', 'VBP'),
#   ('provide', 'VB'),
#   ('android', 'JJ'),
#   ('tv', 'NN'),
#   ('future', 'NN'),
#   ('update', 'IN'),
#   ('overall', 'JJ'),
#   ('good', 'JJ'),
#   ('decision', 'NN'),
#   ('satisfied', 'VBD'),
#   ('tvnokia', 'JJ'),
#   ('backread', 'NN')],
#  [('good', 'JJ'),
#   ('image', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'VBP'),
#   ('quality', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('whole', 'JJ'),
#   ('thing', 'NN'),
#   ('good', 'JJ'),
#   ('thanks', 'NNS'),
#   ('nokia', 'VBP'),
#   ('company', 'NN'),
#   ('launch', 'JJ'),
#   ('new', 'JJ'),
#   ('tv', 'NN'),
#   ('give', 'NN'),
#   ('best', 'JJS'),
#   ('nokia', 'JJ'),
#   ('company', 'NN'),
#   ('special', 'JJ'),
#   ('thanks', 'NNS'),
#   ('nokia', 'VBP'),
#   ('company', 'NN'),
#   ('use', 'NN'),
#   ('sound', 'NN'),
#   ('system', 'NN'),
#   ('jbl', 'JJ'),
#   ('company', 'NN'),
#   ('whole', 'JJ'),
#   ('product', 'NN'),
#   ('top', 'JJ'),
#   ('bottom', 'NN'),
#   ('specialy', 'JJ'),
#   ('tv', 'NN'),
#   ('stand', 'NN'),
#   ('nice', 'JJ'),
#   ('one', 'CD'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'RB'),
#   ('providing', 'VBG'),
#   ('good', 'JJ'),
#   ('service', 'NN'),
#   ('deliver', 'VB'),
#   ('tv', 'NN'),
#   ('installationread', 'NN')],
#  [('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('good', 'JJ'),
#   ('quality', 'NN'),
#   ('sound', 'VBD'),
#   ('awesome', 'JJ'),
#   ('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('happy', 'JJ'),
#   ('customer', 'NN'),
#   ('service', 'NN'),
#   ('support', 'NN'),
#   ('jeeves', 'VBZ'),
#   ('flipkart', 'RB'),
#   ('got', 'JJ'),
#   ('tv', 'NN'),
#   ('th', 'NN'),
#   ('dec', 'NN'),
#   ('pm', 'VBP'),
#   ('one', 'CD'),
#   ('hour', 'NN'),
#   ('got', 'VBD'),
#   ('call', 'JJ'),
#   ('jeeves', 'NNS'),
#   ('installation', 'VBP'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('morning', 'NN'),
#   ('set', 'VBN'),
#   ('truly', 'RB'),
#   ('value', 'NN'),
#   ('others', 'NNS'),
#   ('please', 'VBP'),
#   ('go', 'VB'),
#   ('check', 'NN'),
#   ('connectivityread', 'NN')],
#  [('excellent', 'JJ'),
#   ('tv', 'NN'),
#   ('price', 'NN'),
#   ('pay', 'NN'),
#   ('one', 'CD'),
#   ('must', 'MD'),
#   ('compare', 'VB'),
#   ('tv', 'NN'),
#   ('time', 'NN'),
#   ('cost', 'NN'),
#   ('however', 'RB'),
#   ('category', 'NN'),
#   ('based', 'VBN'),
#   ('price', 'NN'),
#   ('one', 'CD'),
#   ('finest', 'JJS'),
#   ('opinion', 'NN'),
#   ('happy', 'JJ'),
#   ('customer', 'NN'),
#   ('bought', 'VBD'),
#   ('tv', 'NN'),
#   ('writing', 'VBG'),
#   ('review', 'NN'),
#   ('two', 'CD'),
#   ('week', 'NN'),
#   ('usage', 'NN'),
#   ('would', 'MD'),
#   ('like', 'VB'),
#   ('point', 'NN'),
#   ('one', 'CD'),
#   ('must', 'MD'),
#   ('keep', 'VB'),
#   ('delivery', 'NN'),
#   ('service', 'NN'),
#   ('separate', 'JJ'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('dont', 'NN'),
#   ('spread', 'NN'),
#   ('hatred', 'VBD'),
#   ('poor', 'JJ'),
#   ('rating', 'NN'),
#   ('delivery', 'NN'),
#   ('one', 'CD'),
#   ('two', 'CD'),
#   ('day', 'NN'),
#   ('late', 'RB'),
#   ('coming', 'VBG'),
#   ('back', 'RB'),
#   ('tv', 'NN'),
#   ('great', 'JJ'),
#   ('pictureread', 'NN')],
#  [('super', 'JJ'),
#   ('tvvalue', 'NN'),
#   ('moneygood', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('n', 'RB'),
#   ('sound', 'VBD'),
#   ('cast', 'JJ'),
#   ('working', 'VBG'),
#   ('properly', 'RB'),
#   ('everything', 'NN'),
#   ('good', 'JJ'),
#   ('tv', 'NN'),
#   ('suggest', 'VBP'),
#   ('buybut', 'NN'),
#   ('remote', 'VBP'),
#   ('old', 'JJ'),
#   ('model', 'NN'),
#   ('improve', 'VB'),
#   ('one', 'CD'),
#   ('left', 'NN'),
#   ('remote', 'NN'),
#   ('try', 'VB'),
#   ('update', 'JJ'),
#   ('like', 'IN'),
#   ('mi', 'JJ'),
#   ('remote', 'NN'),
#   ('samsung', 'NN'),
#   ('remotesread', 'NN')],
#  [('awesome', 'JJ'),
#   ('experience', 'NN'),
#   ('got', 'VBD'),
#   ('delivery', 'NN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('installation', 'VB'),
#   ('hour', 'NN'),
#   ('great', 'JJ'),
#   ('ultra', 'JJ'),
#   ('hd', 'JJ'),
#   ('tv', 'NN'),
#   ('fantastic', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('mind', 'NN'),
#   ('blowing', 'VBG'),
#   ('sound', 'NN'),
#   ('best', 'JJS'),
#   ('part', 'NN'),
#   ('android', 'VBP'),
#   ('smart', 'JJ'),
#   ('tv', 'NN'),
#   ('update', 'NN'),
#   ('software', 'NN'),
#   ('installation', 'NN'),
#   ('hence', 'NN'),
#   ('remains', 'VBZ'),
#   ('relevant', 'JJ'),
#   ('timeyou', 'NN'),
#   ('download', 'NN'),
#   ('apps', 'NN'),
#   ('google', 'NN'),
#   ('play', 'NN'),
#   ('store', 'NN'),
#   ('play', 'NN'),
#   ('directly', 'RB'),
#   ('phoneapart', 'RB'),
#   ('regular', 'JJ'),
#   ('netflix', 'NN'),
#   ('prime', 'JJ'),
#   ('youtube', 'NN'),
#   ('also', 'RB'),
#   ('watched', 'VBD'),
#   ('hoichoi', 'NN'),
#   ('looking', 'VBG'),
#   ('great', 'JJ'),
#   ('tv', 'NN'),
#   ('bell', 'NN'),
#   ('anread', 'NN')],
#  [('nokia', 'RB'),
#   ('brand', 'NN'),
#   ('trust', 'NN'),
#   ('perfect', 'JJ'),
#   ('tv', 'NN'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('nokia', 'CC'),
#   ('improve', 'VB'),
#   ('sale', 'NN'),
#   ('service', 'NN'),
#   ('everyone', 'NN'),
#   ('buy', 'VB'),
#   ('tv', 'NN'),
#   ('nokia', 'NN'),
#   ('blindlycons', 'NNS'),
#   ('sale', 'NN'),
#   ('service', 'NN'),
#   ('need', 'VBP'),
#   ('improved', 'VBN'),
#   ('completely', 'RB'),
#   ('disappointed', 'JJ'),
#   ('proper', 'JJ'),
#   ('channel', 'NNS'),
#   ('report', 'NN'),
#   ('issue', 'NN'),
#   ('one', 'CD'),
#   ('taking', 'VBG'),
#   ('responsibility', 'NN'),
#   ('issue', 'NN'),
#   ('face', 'NN'),
#   ('first', 'RB'),
#   ('day', 'NN'),
#   ('automatically', 'RB'),
#   ('shut', 'VBN'),
#   ('automatically', 'RB'),
#   ('open', 'JJ'),
#   ('twice', 'RB'),
#   ('watching', 'VBG'),
#   ('tvprospicture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('easy', 'JJ'),
#   ('use', 'NN'),
#   ('overall', 'JJ'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('froread', 'NN')],
#  [('received', 'JJ'),
#   ('product', 'NN'),
#   ('day', 'NN'),
#   ('back', 'RB'),
#   ('really', 'RB'),
#   ('enjoying', 'VBG'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('awesomenokia', 'JJ'),
#   ('tv', 'NN'),
#   ('also', 'RB'),
#   ('giving', 'VBG'),
#   ('good', 'JJ'),
#   ('competition', 'NN'),
#   ('brand', 'NN'),
#   ('product', 'NN'),
#   ('market', 'NN'),
#   ('really', 'RB'),
#   ('feel', 'VB'),
#   ('worth', 'IN'),
#   ('purchasing', 'VBG'),
#   ('within', 'IN'),
#   ('budgetthanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('nokiaread', 'JJ')],
#  [('grt', 'JJ'),
#   ('tv', 'NN'),
#   ('impressive', 'JJ'),
#   ('sound', 'NN'),
#   ('remote', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('averageonly', 'RB'),
#   ('let', 'VBP'),
#   ('doesnt', 'VB'),
#   ('support', 'NN'),
#   ('g', 'NN'),
#   ('wiifiibut', 'NN'),
#   ('u', 'JJ'),
#   ('connect', 'NN'),
#   ('via', 'IN'),
#   ('rj', 'NN'),
#   ('lan', 'NN'),
#   ('cable', 'NN'),
#   ('fast', 'NN'),
#   ('browsingread', 'NN')],
#  [('spectacular', 'JJ'),
#   ('stunning', 'VBG'),
#   ('nokia', 'JJ'),
#   ('tvi', 'NN'),
#   ('believe', 'VBP'),
#   ('im', 'NN'),
#   ('using', 'VBG'),
#   ('personally', 'RB'),
#   ('product', 'NN'),
#   ('best', 'JJS'),
#   ('one', 'CD'),
#   ('inch', 'NN'),
#   ('wide', 'JJ'),
#   ('screen', 'JJ'),
#   ('tv', 'NN'),
#   ('display', 'NN'),
#   ('sound', 'NN'),
#   ('operation', 'NN'),
#   ('really', 'RB'),
#   ('smooth', 'JJ'),
#   ('fantastic', 'JJ'),
#   ('youre', 'NN'),
#   ('looking', 'VBG'),
#   ('dream', 'NN'),
#   ('tv', 'NN'),
#   ('recommended', 'VBD'),
#   ('buy', 'NN'),
#   ('nokia', 'IN'),
#   ('inch', 'JJ'),
#   ('tv', 'NN'),
#   ('great', 'JJ'),
#   ('collaboration', 'NN'),
#   ('nokia', 'FW'),
#   ('jbl', 'NN'),
#   ('flipkartread', 'NN')],
#  [('nokia', 'DT'),
#   ('come', 'VBN'),
#   ('back', 'RB'),
#   ('bang', 'JJ'),
#   ('look', 'NN'),
#   ('like', 'IN'),
#   ('dominate', 'NN'),
#   ('disrupt', 'JJ'),
#   ('tv', 'NN'),
#   ('market', 'NN'),
#   ('stay', 'VB'),
#   ('course', 'NN'),
#   ('month', 'NN'),
#   ('absolutely', 'RB'),
#   ('love', 'JJ'),
#   ('tv', 'NN'),
#   ('pro', 'FW'),
#   ('great', 'JJ'),
#   ('build', 'JJ'),
#   ('awesome', 'JJ'),
#   ('presence', 'NN'),
#   ('living', 'NN'),
#   ('room', 'NN'),
#   ('stand', 'VBP'),
#   ('absolutely', 'RB'),
#   ('gorgeous', 'JJ'),
#   ('overall', 'JJ'),
#   ('tv', 'NN'),
#   ('appears', 'VBZ'),
#   ('quite', 'RB'),
#   ('sophisticated', 'JJ'),
#   ('great', 'JJ'),
#   ('tv', 'NN'),
#   ('picture', 'NN'),
#   ('color', 'NN'),
#   ('contrast', 'NN'),
#   ('depth', 'NN'),
#   ('black', 'JJ'),
#   ('quite', 'RB'),
#   ('impressive', 'JJ'),
#   ('android', 'JJ'),
#   ('work', 'NN'),
#   ('like', 'IN'),
#   ('charm', 'NN'),
#   ('find', 'VBP'),
#   ('apps', 'JJ'),
#   ('work', 'NN'),
#   ('google', 'NN'),
#   ('play', 'NN'),
#   ('store', 'NN'),
#   ('easily', 'RB'),
#   ('sound', 'VBD'),
#   ('amazing', 'JJ'),
#   ('jbl', 'NN'),
#   ('souread', 'NN')],
#  [('nokia', 'RB'),
#   ('best', 'JJS'),
#   ('android', 'JJ'),
#   ('tvi', 'NN'),
#   ('never', 'RB'),
#   ('saw', 'VBD'),
# ...
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('display', 'NN'), ('bleedingread', 'NN')],
#  [('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('goodread', 'NN')],
#  [('worst', 'JJ'), ('picture', 'NN'), ('everread', 'NN')],
#  [('white', 'JJ'), ('patch', 'NN'), ('black', 'JJ'), ('creenread', 'NN')],
#  [('got', 'VBD'),
#   ('broken', 'JJ'),
#   ('piece', 'NN'),
#   ('replaced', 'VBD'),
#   ('itnow', 'JJ'),
#   ('received', 'JJ'),
#   ('tv', 'NN'),
#   ('prime', 'JJ'),
#   ('video', 'NN'),
#   ('working', 'VBG'),
#   ('stop', 'NN'),
#   ('shuts', 'NNS'),
#   ('watching', 'VBG'),
#   ('netflix', 'JJ'),
#   ('nokia', 'NN'),
#   ('came', 'VBD'),
#   ('good', 'JJ'),
#   ('tv', 'NN'),
#   ('lot', 'NN'),
#   ('problem', 'NN'),
#   ('need', 'VBP'),
#   ('revise', 'NN'),
#   ('device', 'NN'),
#   ('sad', 'JJ'),
#   ('purchase', 'NN'),
#   ('sureread', 'NN')],
#  [('continuous', 'JJ'),
#   ('lag', 'NN'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('playingvu', 'NN'),
#   ('better', 'RBR'),
#   ('nokia', 'JJ'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('playing', 'VBG'),
#   ('issueread', 'NN')],
#  [('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('term', 'NN'),
#   ('picture', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('thr', 'JJ'),
#   ('issue', 'NN'),
#   ('tell', 'VBP'),
#   ('color', 'NN'),
#   ('bleeding', 'VBG'),
#   ('tv', 'NN'),
#   ('day', 'NN'),
#   ('delivery', 'NN'),
#   ('next', 'JJ'),
#   ('day', 'NN'),
#   ('installation', 'NN'),
#   ('happy', 'JJ'),
#   ('purchase', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipkartread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('tv', 'NN'),
#   ('yes', 'NNS'),
#   ('minor', 'JJ'),
#   ('screen', 'NN'),
#   ('bleeding', 'VBG'),
#   ('issue', 'NN'),
#   ('doesnt', 'NN'),
#   ('affect', 'JJ'),
#   ('case', 'NN'),
#   ('time', 'NN'),
#   ('wont', 'JJ'),
#   ('notice', 'NN'),
#   ('youtube', 'NN'),
#   ('video', 'NN'),
#   ('find', 'VBP'),
#   ('effect', 'NN'),
#   ('screen', 'NN'),
#   ('bleeding', 'VBG'),
#   ('accordingly', 'RB'),
#   ('decision', 'NN'),
#   ('takenread', 'NN')],
#  [('use', 'NN'),
#   ('dayssound', 'NN'),
#   ('goodpicture', 'NN'),
#   ('quality', 'NN'),
#   ('goodconnectivity', 'NN'),
#   ('goodyes', 'VBP'),
#   ('value', 'NN'),
#   ('moneygoogle', 'NN'),
#   ('assistant', 'NN'),
#   ('slowlag', 'NN'),
#   ('video', 'NN'),
#   ('volume', 'NN'),
#   ('updownexpecting', 'VBG'),
#   ('overcome', 'JJ'),
#   ('bug', 'NN'),
#   ('next', 'JJ'),
#   ('updateread', 'NN')],
#  [('uptodate', 'JJ'),
#   ('featuring', 'VBG'),
#   ('tvenglish', 'JJ'),
#   ('movie', 'NN'),
#   ('hd', 'NN'),
#   ('channel', 'NN'),
#   ('looking', 'VBG'),
#   ('like', 'IN'),
#   ('theaterread', 'NN')],
#  [('overall', 'JJ'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('amazing', 'VBG'),
#   ('sound', 'JJ'),
#   ('quality', 'JJ'),
#   ('average', 'JJ'),
#   ('video', 'NN'),
#   ('qualityread', 'NN')],
#  [('remote', 'JJ'),
#   ('application', 'NN'),
#   ('note', 'NN'),
#   ('working', 'VBG'),
#   ('normallymxplayer', 'NN'),
#   ('antivirus', 'JJ'),
#   ('application', 'NN'),
#   ('note', 'NN'),
#   ('workingread', 'NN')],
#  [('excellent', 'JJ'),
#   ('performance', 'NN'),
#   ('nive', 'JJ'),
#   ('better', 'JJR'),
#   ('tvread', 'NN')],
#  [('unit', 'NN'),
#   ('wall', 'NN'),
#   ('mounted', 'VBD'),
#   ('difficult', 'JJ'),
#   ('connect', 'JJ'),
#   ('pendrive', 'JJ'),
#   ('settop', 'NN'),
#   ('box', 'NN'),
#   ('wireread', 'NN')],
#  [('goodread', 'NN')],
#  [('worth', 'JJ'),
#   ('money', 'NN'),
#   ('nice', 'JJ'),
#   ('tv', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('goodread', 'NN')],
#  [('good', 'JJ'),
#   ('budget', 'NN'),
#   ('nokia', 'JJ'),
#   ('smart', 'JJ'),
#   ('tvread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('happy', 'JJ'),
#   ('productread', 'NN')],
#  [('value', 'NN'),
#   ('moneypicture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('awesome', 'IN'),
#   ('overall', 'JJ'),
#   ('worth', 'NN'),
#   ('dealhowever', 'NN'),
#   ('prime', 'JJ'),
#   ('video', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('weak', 'JJ'),
#   ('sometimes', 'RB'),
#   ('patch', 'VBP'),
#   ('screen', 'JJ'),
#   ('little', 'JJ'),
#   ('shakingdo', 'NN'),
#   ('anyone', 'NN'),
#   ('get', 'NN'),
#   ('kind', 'NN'),
#   ('problemread', 'NN')],
#  [('jbl', 'NN'),
#   ('speaker', 'NN'),
#   ('effective', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('goodread', 'NN')],
#  [('amazing', 'VBG'),
#   ('option', 'NN'),
#   ('available', 'JJ'),
#   ('audio', 'JJ'),
#   ('quality', 'NN'),
#   ('satisfying', 'VBG'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('also', 'RB'),
#   ('connectivity', 'NN'),
#   ('option', 'NN'),
#   ('decent', 'NN'),
#   ('enoughread', 'NN')],
#  [('price', 'NN'),
#   ('segment', 'NN'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('best', 'JJS'),
#   ('love', 'NN'),
#   ('product', 'NN'),
#   ('sound', 'NN'),
#   ('jbl', 'JJ'),
#   ('aswm', 'NN'),
#   ('aswm', 'JJ'),
#   ('perchase', 'NN'),
#   ('read', 'NN')],
#  [('video', 'NN'),
#   ('clarity', 'NN'),
#   ('excellent', 'NN'),
#   ('go', 'VBP'),
#   ('nokia', 'RB'),
#   ('sound', 'JJ'),
#   ('k', 'NN'),
#   ('superb', 'NN'),
#   ('netflix', 'JJ'),
#   ('prime', 'JJ'),
#   ('youtube', 'NN'),
#   ('updatedread', 'NN')],
#  [('unbelievable', 'JJ'),
#   ('productbut', 'JJ'),
#   ('tv', 'NN'),
#   ('stand', 'NN'),
#   ('getting', 'VBG'),
#   ('electric', 'JJ'),
#   ('currentand', 'NN'),
#   ('taking', 'VBG'),
#   ('much', 'JJ'),
#   ('time', 'NN'),
#   ('time', 'NN'),
#   ('deliverat', 'VB'),
#   ('one', 'CD'),
#   ('two', 'CD'),
#   ('month', 'NN'),
#   ('value', 'NN'),
#   ('moneyand', 'VBP'),
#   ('better', 'JJR'),
#   ('qualityread', 'NN')],
#  [('screen', 'NN'),
#   ('bleedingrandomly', 'RB'),
#   ('tv', 'JJ'),
#   ('restart', 'NN'),
#   ('playing', 'VBG'),
#   ('apps', 'JJ'),
#   ('amazon', 'JJ'),
#   ('prime', 'JJ'),
#   ('video', 'NN'),
#   ('hotstar', 'NN'),
#   ('netflix', 'RB'),
#   ('etcnot', 'JJ'),
#   ('manufacturing', 'VBG'),
#   ('nokia', 'JJ'),
#   ('branding', 'NN'),
#   ('actually', 'RB'),
#   ('made', 'VBD'),
#   ('skyworth', 'JJ'),
#   ('india', 'JJ'),
#   ('dont', 'NN'),
#   ('buy', 'NN'),
#   ('tvread', 'NN')],
#  [('weast', 'NN'),
#   ('moneyi', 'NN'),
#   ('user', 'NN'),
#   ('nokia', 'JJ'),
#   ('tvbad', 'NN'),
#   ('connectivity', 'NN'),
#   ('screen', 'NN'),
#   ('mirroring', 'VBG'),
#   ('badread', 'NN')],
#  [('wow', 'JJ'),
#   ('tv', 'NN'),
#   ('volume', 'NN'),
#   ('average', 'JJ'),
#   ('picture', 'NN'),
#   ('fade', 'JJ'),
#   ('side', 'NN'),
#   ('view', 'NN'),
#   ('budget', 'NN'),
#   ('go', 'VB'),
#   ('lg', 'JJ'),
#   ('samsung', 'NN'),
#   ('wall', 'NN'),
#   ('mount', 'NN'),
#   ('block', 'NN'),
#   ('backside', 'IN'),
#   ('port', 'NN'),
#   ('need', 'VBP'),
#   ('p', 'NN'),
#   ('higher', 'JJR'),
#   ('input', 'NN'),
#   ('see', 'VBP'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sd', 'VBP'),
#   ('channel', 'NNS'),
#   ('unimpressiveread', 'JJ')],
#  [('good', 'JJ'),
#   ('buy', 'NN'),
#   ('th', 'NNS'),
#   ('day', 'NN'),
#   ('could', 'MD'),
#   ('see', 'VB'),
#   ('rash', 'JJ'),
#   ('display', 'NN'),
#   ('couldnt', 'NN'),
#   ('see', 'VBP'),
#   ('switching', 'VBG'),
#   ('tv', 'NN'),
#   ('switching', 'VBG'),
#   ('back', 'RP'),
#   ('sure', 'JJ'),
#   ('problemread', 'NN')],
#  [('tv', 'NN'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('sound', 'NN'),
#   ('goodthere', 'RB'),
#   ('problem', 'NN'),
#   ('backlight', 'JJ'),
#   ('issue', 'NN'),
#   ('light', 'VBD'),
#   ('dark', 'JJ'),
#   ('background', 'NN'),
#   ('backlight', 'VBD'),
#   ('bleeding', 'VBG'),
#   ('seenread', 'NN')],
#  [('sound', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('extraordinaryread', 'NN')],
#  [('worth', 'JJ'),
#   ('money', 'NN'),
#   ('sometimes', 'RB'),
#   ('getting', 'VBG'),
#   ('lagging', 'VBG'),
#   ('using', 'VBG'),
#   ('remote', 'VB'),
#   ('control', 'NN'),
#   ('new', 'JJ'),
#   ('software', 'NN'),
#   ('update', 'JJ'),
#   ('received', 'VBD'),
#   ('day', 'NN'),
#   ('usingread', 'JJ')],
#  [('one', 'CD'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('nokianokia', 'NN'),
#   ('really', 'RB'),
#   ('great', 'JJ'),
#   ('worki', 'NN'),
#   ('think', 'VBP'),
#   ('nokia', 'JJ'),
#   ('increase', 'NN'),
#   ('price', 'NN'),
#   ('productbecause', 'IN'),
#   ('quality', 'NN'),
#   ('excellent', 'JJ'),
#   ('tv', 'NN'),
#   ('beat', 'NN'),
#   ('sony', 'NN'),
#   ('tvone', 'NN'),
#   ('quality', 'NN'),
#   ('display', 'VBP'),
#   ('sound', 'VBN'),
#   ('qualityread', 'JJ')],
#  [('superread', 'NN')],
#  [('bad', 'JJ'),
#   ('product', 'NN'),
#   ('worst', 'JJS'),
#   ('service', 'NN'),
#   ('provider', 'NN'),
#   ('flipkart', 'NN'),
#   ('jeevesread', 'NN')],
#  [('value', 'NN'), ('money', 'NN'), ('read', 'VB')],
#  [('purchased', 'VBN'),
#   ('product', 'NN'),
#   ('december', 'NN'),
#   ('picture', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('goodbut', 'NN'),
#   ('im', 'VBP'),
#   ('facing', 'VBG'),
#   ('android', 'RP'),
#   ('loading', 'VBG'),
#   ('problem', 'NN'),
#   ('switch', 'NN'),
#   ('tv', 'NN'),
#   ('able', 'JJ'),
#   ('access', 'NN'),
#   ('apps', 'JJ'),
#   ('feature', 'NN'),
#   ('tvwithin', 'IN'),
#   ('one', 'CD'),
#   ('year', 'NN'),
#   ('type', 'NN'),
#   ('issue', 'NN'),
#   ('never', 'RB'),
#   ('seen', 'VBN'),
#   ('new', 'JJ'),
#   ('tv', 'NN'),
#   ('experience', 'NN'),
#   ('request', 'NN'),
#   ('solve', 'NN'),
#   ('issue', 'NN'),
#   ('soon', 'RB'),
#   ('possibledont', 'RB'),
#   ('make', 'VB'),
#   ('customer', 'NN'),
#   ('think', 'NN'),
#   ('refer', 'VBP'),
#   ('customer', 'NN'),
#   ('purchaseread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('goodread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('goodread', 'NN')],
#  [('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('biggest', 'JJS'),
#   ('positive', 'JJ'),
#   ('built', 'VBN'),
#   ('okay', 'JJ'),
#   ('bezel', 'NN'),
#   ('thin', 'JJ'),
#   ('worth', 'JJ'),
#   ('money', 'NN'),
#   ('paid', 'VBN'),
#   ('based', 'VBN'),
#   ('day', 'NN'),
#   ('trial', 'NN'),
#   ('period', 'NN'),
#   ('update', 'JJ'),
#   ('review', 'NN'),
#   ('monthsread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('term', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('google', 'VBP'),
#   ('play', 'NN'),
#   ('apps', 'NN'),
#   ('installed', 'VBD'),
#   ('android', 'JJ'),
#   ('phone', 'NN'),
#   ('support', 'NN'),
#   ('tv', 'NN'),
#   ('would', 'MD'),
#   ('better', 'VB'),
#   ('option', 'NN'),
#   ('much', 'JJ'),
#   ('ask', 'NN'),
#   ('might', 'MD'),
#   ('goodimpressed', 'VB'),
#   ('way', 'NN'),
#   ('tv', 'NN'),
#   ('built', 'VBN'),
#   ('designread', 'NN')],
#  [('excellent', 'JJ'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('system', 'NN'),
#   ('greatread', 'NN')],
#  [('writing', 'VBG'),
#   ('review', 'NN'),
#   ('using', 'VBG'),
#   ('tv', 'JJ'),
#   ('month', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('superb', 'NN'),
#   ('also', 'RB'),
#   ('ordered', 'VBD'),
#   ('motorola', 'JJ'),
#   ('tv', 'NN'),
#   ('along', 'IN'),
#   ('week', 'NN'),
#   ('difference', 'NN'),
#   ('could', 'MD'),
#   ('see', 'VB'),
#   ('clear', 'JJ'),
#   ('difference', 'NN'),
#   ('among', 'IN'),
#   ('two', 'CD'),
#   ('build', 'VBP'),
#   ('quality', 'NN'),
#   ('nokia', 'VBP'),
#   ('really', 'RB'),
#   ('strong', 'JJ'),
#   ('say', 'VBP'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('panel', 'NN'),
#   ('quality', 'NN'),
#   ('plastic', 'NN'),
#   ('build', 'VBP'),
#   ('back', 'RB'),
#   ('panel', 'NN'),
#   ('etc', 'NN'),
#   ('strong', 'JJ'),
#   ('compared', 'VBN'),
#   ('tv', 'NN'),
#   ('jbl', 'NN'),
#   ('soundno', 'VBD'),
#   ('one', 'CD'),
#   ('beat', 'NN'),
#   ('price', 'NN'),
#   ('slightly', 'RB'),
#   ('regular', 'JJ'),
#   ('tvsbut', 'NN'),
#   ('justifies', 'NNS'),
#   ('price', 'NN'),
#   ('didread', 'NN')],
#  [('really', 'RB'),
#   ('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('launched', 'VBN'),
#   ('nokia', 'RB'),
#   ('sound', 'JJ'),
#   ('system', 'NN'),
#   ('jbl', 'NN'),
#   ('really', 'RB'),
#   ('mind', 'JJ'),
#   ('blowingpicture', 'NN'),
#   ('quality', 'NN'),
#   ('goodyes', 'NNS'),
#   ('feel', 'VBP'),
#   ('connectivity', 'JJ'),
#   ('issue', 'NN'),
#   ('wrt', 'VBD'),
#   ('screen', 'JJ'),
#   ('mirroringoverall', 'NN'),
#   ('worth', 'IN'),
#   ('value', 'NN'),
#   ('moneyread', 'NN')],
#  [('using', 'VBG'),
#   ('since', 'IN'),
#   ('weekafter', 'NN'),
#   ('installation', 'NN'),
#   ('facing', 'VBG'),
#   ('wifi', 'JJ'),
#   ('connection', 'NN'),
#   ('issue', 'NN'),
#   ('wifi', 'NN'),
#   ('disconnected', 'VBD'),
#   ('utube', 'JJ'),
#   ('restart', 'NN'),
#   ('connect', 'NN'),
#   ('manually', 'RB'),
#   ('raised', 'VBD'),
#   ('complaint', 'NN'),
#   ('jeeves', 'NNS'),
#   ('executive', 'VBP'),
#   ('came', 'VBD'),
#   ('upgraded', 'JJ'),
#   ('software', 'NN'),
#   ('dont', 'JJ'),
#   ('issue', 'NN'),
#   ('running', 'VBG'),
#   ('smoothvalue', 'JJ'),
#   ('money', 'NN'),
#   ('dealit', 'NN'),
#   ('backed', 'VBD'),
#   ('two', 'CD'),
#   ('trusted', 'VBD'),
#   ('brandsnokia', 'NNS'),
#   ('flipkartif', 'VB'),
#   ('something', 'NN'),
#   ('go', 'VB'),
#   ('wrong', 'JJ'),
#   ('always', 'RB'),
#   ('cheersread', 'VBP')],
#  [('good', 'JJ'), ('picture', 'NN'), ('qualityread', 'NN')],
#  [('watching', 'VBG'),
#   ('youtube', 'PRP'),
#   ('video', 'JJ'),
#   ('whenever', 'WRB'),
#   ('volume', 'NN'),
#   ('button', 'NN'),
#   ('pressed', 'VBN'),
#   ('video', 'NN'),
#   ('get', 'NN'),
#   ('jump', 'NN'),
#   ('feel', 'VBP'),
#   ('like', 'IN'),
#   ('twist', 'NN'),
#   ('volumeread', 'NN')],
#  [('purshaed', 'JJ'),
#   ('month', 'NN'),
#   ('back', 'RB'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('see', 'VB'),
#   ('display', 'NN'),
#   ('sound', 'VB'),
#   ('heard', 'RB'),
#   ('worst', 'JJS'),
#   ('experienceread', 'NN')],
#  [('tv', 'NN'),
#   ('doesnt', 'NN'),
#   ('support', 'NN'),
#   ('arc', 'NN'),
#   ('regarding', 'VBG'),
#   ('raised', 'VBN'),
#   ('complaint', 'NN'),
#   ('nokia', 'NN'),
#   ('customer', 'NN'),
#   ('care', 'NN'),
#   ('technician', 'JJ'),
#   ('visited', 'VBD'),
#   ('told', 'JJ'),
#   ('hdmi', 'NN'),
#   ('arc', 'NN'),
#   ('feasibility', 'NN'),
#   ('connected', 'VBN'),
#   ('sony', 'JJ'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('model', 'NN'),
#   ('iv', 'NN'),
#   ('found', 'VBD'),
#   ('working', 'VBG'),
#   ('technician', 'JJ'),
#   ('checked', 'VBN'),
#   ('tech', 'JJ'),
#   ('support', 'NN'),
#   ('confirmed', 'VBD'),
#   ('nokia', 'JJ'),
#   ('tv', 'NN'),
#   ('doesnt', 'NN'),
#   ('support', 'NN'),
#   ('sony', 'VBD'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('real', 'JJ'),
#   ('disappointment', 'NN'),
#   ('watch', 'NN'),
#   ('movie', 'NN'),
#   ('via', 'IN'),
#   ('home', 'NN'),
#   ('theater', 'NN'),
#   ('suspect', 'VBP'),
#   ('arc', 'IN'),
#   ('working', 'VBG'),
#   ('blame', 'NN'),
#   ('pushed', 'VBN'),
#   ('noread', 'NN')],
#  [('goodread', 'NN')],
#  [('overall', 'JJ'),
#   ('okkk', 'VBZ'),
#   ('one', 'CD'),
#   ('issue', 'NN'),
#   ('white', 'JJ'),
#   ('patch', 'NN'),
#   ('black', 'JJ'),
#   ('screen', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('jbl', 'NN'),
#   ('mind', 'NN'),
#   ('blowingnice', 'NN'),
#   ('purchaseread', 'NN')],
#  [('good', 'JJ'), ('sound', 'NN'), ('superread', 'NN')],
#  [('best', 'JJS'), ('quality', 'NN'), ('nokiaread', 'NN')],
#  [('although', 'IN'),
#   ('thing', 'NN'),
#   ('good', 'JJ'),
#   ('tv', 'NN'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('found', 'VBD'),
#   ('display', 'NN'),
#   ('bleeding', 'NN'),
#   ('problem', 'NN'),
#   ('switch', 'NN'),
#   ('tv', 'NN'),
#   ('apart', 'RB'),
#   ('worth', 'JJ'),
#   ('money', 'NN'),
#   ('talking', 'VBG'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('facility', 'NN'),
#   ('within', 'IN'),
#   ('price', 'NN'),
#   ('rangeread', 'NN')],
#  [('nice', 'JJ'), ('tv', 'NN'), ('sound', 'NN'), ('bestread', 'NN')],
#  [('bleeding', 'VBG'),
#   ('screen', 'JJ'),
#   ('sound', 'JJ'),
#   ('okay', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('good', 'JJ'),
#   ('value', 'NN'),
#   ('moneyread', 'NN')],
#  [('got', 'VBD'),
#   ('today', 'NN'),
#   ('wow', 'VBP'),
#   ('five', 'CD'),
#   ('star', 'NNS'),
#   ('really', 'RB'),
#   ('amazing', 'VBG'),
#   ('product', 'NN'),
#   ('quick', 'JJ'),
#   ('look', 'NN'),
#   ('really', 'RB'),
#   ('amazing', 'JJ'),
#   ('stunning', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('easy', 'JJ'),
#   ('switching', 'VBG'),
#   ('various', 'JJ'),
#   ('apps', 'JJ'),
#   ('feature', 'NN'),
#   ('absolutely', 'RB'),
#   ('delay', 'VBD'),
#   ('good', 'JJ'),
#   ('connectivity', 'NN'),
#   ('may', 'MD'),
#   ('due', 'VB'),
#   ('availability', 'NN'),
#   ('ram', 'JJ'),
#   ('storage', 'NN'),
#   ('quick', 'JJ'),
#   ('delivery', 'NN'),
#   ('professional', 'JJ'),
#   ('installation', 'NN'),
#   ('better', 'RBR'),
#   ('use', 'NN'),
#   ('big', 'JJ'),
#   ('room', 'NN'),
#   ('tv', 'NN'),
#   ('size', 'NN'),
#   ('big', 'JJ'),
#   ('nokia', 'NN'),
#   ('congrats', 'NNS'),
#   ('great', 'JJ'),
#   ('productread', 'NN')]]

# %%
Adjective = []
Adverb = []
CordinatingConjunction = []
SubordinatingConjuction = []
Interjection = []
Noun = []
Verb = []
PersonalPronoun = []
predeterminer = []
Determiner = []

# %%
for value in pos:
  AdjectiveCount = 0
  AdverbCount = 0
  CordinatingConjunctionCount = 0
  SubordinatingConjuctionCount = 0
  InterjectionCount = 0
  NounCount = 0
  VerbCount = 0
  PersonalPronounCount = 0
  predeterminerCount = 0
  DeterminerCount = 0
  for word,tag in value:
    if tag == 'JJ':
      AdjectiveCount = AdjectiveCount + 1
    elif tag == 'RB':
      AdverbCount = AdverbCount + 1
    elif tag == 'CC':
      CordinatingConjunctionCount = CordinatingConjunctionCount + 1
    elif tag == 'UH':
      InterjectionCount = InterjectionCount + 1
    elif tag == 'NN':
      NounCount = NounCount + 1
    elif tag == 'VR':
      VerbCount = VerbCount + 1
    elif tag == 'PRP':
      PersonalPronounCount = PersonalPronounCount + 1
    elif tag == 'PDT':
      predeterminerCount = predeterminerCount + 1
    elif tag == 'DT':
      DeterminerCount = DeterminerCount + 1
    elif tag == 'IN':
      SubordinatingConjuctionCount = SubordinatingConjuctionCount + 1
  Adjective.append(AdjectiveCount)
  Adverb.append(AdverbCount)
  CordinatingConjunction.append(CordinatingConjunctionCount)
  Interjection.append(InterjectionCount)
  Noun.append(NounCount)
  Verb.append(VerbCount)
  PersonalPronoun.append(PersonalPronounCount)
  predeterminer.append(predeterminerCount)
  Determiner.append(DeterminerCount)
  SubordinatingConjuction.append(SubordinatingConjuctionCount)

# %%
df['Number of Adjectives'] = Adjective
df['Number of Adverbs'] = Adverb
df['Number of Cordinating Conjunctions'] = CordinatingConjunction
df['Number of Interjections'] = Interjection
df['Number of Nouns'] = Noun
df['Number of Verbs'] = Verb
df['Number of Personal Pronouns'] = PersonalPronoun
df['Number of Predeterminers'] = predeterminer
df['Number of Determiners'] = Determiner
df['Number of Subordinating Conjuctions'] = SubordinatingConjuction
df
# Out:
#                                      Glimpse of Review  ... Sentenece Length
# 0    Review from Technology Gyan: Almost everything...  ...              505
# 1                                    Terrific purchase  ...              506
# 2                                            Brilliant  ...              394
# 3                                  Best in the market!  ...              509
# 4                                          Pretty good  ...              500
# ..                                                 ...  ...              ...
# 505                                Best in the market!  ...               31
# 506                                           Horrible  ...              253
# 507                                          Wonderful  ...               37
# 508                                               Nice  ...              100
# 509                                     Simply awesome  ...              413
#
# [510 rows x 15 columns]

# %% [markdown]
# # **Linguistic features**

# %% [markdown]
# **Number of right-branching nodes**

# %%
RightBranchingNodes = []
nlp = spacy.load("en_core_web_sm")
for sentence in df['After Preprocessing']:
  doc = nlp(sentence)
  try:
    RightBranchingNodes.append(doc[0].n_rights)
  except:
    RightBranchingNodes.append('No')
df['Number of Right Branching Nodes'] = RightBranchingNodes

# %% [markdown]
# **Sentence Length**

# %%
df['Sentenece Length'] = df['Full Review'].apply(lambda x: len(x))
df
# Out:
#                                      Glimpse of Review  ... Sentenece Length
# 0    Review from Technology Gyan: Almost everything...  ...              505
# 1                                    Terrific purchase  ...              506
# 2                                            Brilliant  ...              394
# 3                                  Best in the market!  ...              509
# 4                                          Pretty good  ...              500
# ..                                                 ...  ...              ...
# 505                                Best in the market!  ...               31
# 506                                           Horrible  ...              253
# 507                                          Wonderful  ...               37
# 508                                               Nice  ...              100
# 509                                     Simply awesome  ...              413
#
# [510 rows x 15 columns]
